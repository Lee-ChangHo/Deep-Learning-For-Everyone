# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers, initializers, regularizers, metrics

# %%
np.random.seed(3)
tf.random.set_seed(3)

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,  # 수평 대칭 이미지를 50% 확률로 만들어 추가
                                   width_shift_range=0.1,  # 전체 크기의 10% 범위에서 좌우로 이동
                                   height_shift_range=0.1,  # 마찬가지로 위아래로 이동
                                                            # rotation_range = 5,
                                                            # shear_range = 0.7,
                                                            # zoom_range = [0.9, 2.2]
                                                            # vertical_flip = True,
                                   fill_mode='nearest')

train_generator = train_datagen.flow_from_directory('./train',       # 테스트셋이 있는 폴더 위치
                                                    target_size=(150, 150), 
                                                    batch_size=5, 
                                                    class_mode='binary')
# Out:
# Found 160 images belonging to 2 classes.

# %%
# 테스트셋은 이미지 부풀리기 과정을 진행하지 않음
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
'./test',
target_size=(150,150),
batch_size=5,
class_mode='binary')
# Out:
# Found 120 images belonging to 2 classes.

# %%
# 앞서 배운 CNN 모델을 만들어 적용하기
model=Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150,150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))

# %%
# 모델 컴파일
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizers.Adam(learning_rate=0.0002),
              metrics = ['accuracy'])

# %%
# 모델 실행
history = model.fit_generator(
train_generator,
steps_per_epoch=100,
epochs=20,
validation_data=test_generator,
validation_steps=4)

# 결과를 그래프로 표현하는 부분
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker='.', c='red', label='Trainset_acc')
plt.plot(x_len, y_vloss, marker='.', c="cornflowerblue", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
# Out:
# Epoch 1/20
# 100/100 [==============================] - 8s 81ms/step - loss: 0.6965 - accuracy: 0.5060 - val_loss: 0.6861 - val_accuracy: 0.5000
# Epoch 2/20
# 100/100 [==============================] - 8s 78ms/step - loss: 0.6748 - accuracy: 0.5920 - val_loss: 0.7151 - val_accuracy: 0.5000
# Epoch 3/20
# 100/100 [==============================] - 7s 74ms/step - loss: 0.6496 - accuracy: 0.6120 - val_loss: 0.5960 - val_accuracy: 0.7500
# Epoch 4/20
# 100/100 [==============================] - 8s 75ms/step - loss: 0.5479 - accuracy: 0.7420 - val_loss: 0.4549 - val_accuracy: 0.6500
# Epoch 5/20
# 100/100 [==============================] - 8s 76ms/step - loss: 0.4672 - accuracy: 0.8020 - val_loss: 0.3359 - val_accuracy: 0.9000
# Epoch 6/20
# 100/100 [==============================] - 7s 75ms/step - loss: 0.3322 - accuracy: 0.8700 - val_loss: 0.1443 - val_accuracy: 1.0000
# Epoch 7/20
# 100/100 [==============================] - 8s 77ms/step - loss: 0.2318 - accuracy: 0.8980 - val_loss: 0.1117 - val_accuracy: 1.0000
# Epoch 8/20
# 100/100 [==============================] - 8s 78ms/step - loss: 0.2244 - accuracy: 0.9100 - val_loss: 0.1288 - val_accuracy: 0.9000
# Epoch 9/20
# 100/100 [==============================] - 7s 74ms/step - loss: 0.1520 - accuracy: 0.9560 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 10/20
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1130 - accuracy: 0.9600 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 11/20
# 100/100 [==============================] - 8s 81ms/step - loss: 0.1054 - accuracy: 0.9620 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 12/20
# 100/100 [==============================] - 7s 74ms/step - loss: 0.1096 - accuracy: 0.9640 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 13/20
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1282 - accuracy: 0.9580 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 14/20
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0929 - accuracy: 0.9700 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 15/20
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0937 - accuracy: 0.9700 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 16/20
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0858 - accuracy: 0.9700 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 17/20
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0991 - accuracy: 0.9740 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 18/20
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0716 - accuracy: 0.9760 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 19/20
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0686 - accuracy: 0.9740 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 20/20
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0466 - accuracy: 0.9840 - val_loss: 0.0018 - val_accuracy: 1.0000
