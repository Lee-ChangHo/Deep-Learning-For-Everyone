# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7088  g_loss:0.6902
# epoch:1  d_loss:0.4522  g_loss:0.3372
# epoch:2  d_loss:0.4974  g_loss:0.0869
# epoch:3  d_loss:0.5612  g_loss:0.0402
# epoch:4  d_loss:0.5678  g_loss:0.0702
# epoch:5  d_loss:0.5294  g_loss:0.2230
# epoch:6  d_loss:0.4931  g_loss:0.4969
# epoch:7  d_loss:0.5091  g_loss:0.7294
# epoch:8  d_loss:0.5188  g_loss:0.7720
# epoch:9  d_loss:0.4829  g_loss:0.7925
# epoch:10  d_loss:0.4095  g_loss:0.8514
# epoch:11  d_loss:0.3837  g_loss:1.0228
# epoch:12  d_loss:0.3360  g_loss:1.2421
# epoch:13  d_loss:0.3409  g_loss:1.6401
# epoch:14  d_loss:0.4513  g_loss:1.6920
# epoch:15  d_loss:0.5749  g_loss:1.6932
# epoch:16  d_loss:0.6355  g_loss:1.6766
# epoch:17  d_loss:0.8147  g_loss:1.1405
# epoch:18  d_loss:0.6972  g_loss:0.9448
# epoch:19  d_loss:0.4821  g_loss:0.8751
# epoch:20  d_loss:0.4176  g_loss:0.8683
# epoch:21  d_loss:0.4727  g_loss:0.8415
# epoch:22  d_loss:0.4149  g_loss:0.7115
# epoch:23  d_loss:0.3437  g_loss:0.6595
# epoch:24  d_loss:0.3301  g_loss:0.9083
# epoch:25  d_loss:0.3511  g_loss:0.9978
# epoch:26  d_loss:0.4027  g_loss:0.9747
# epoch:27  d_loss:0.3535  g_loss:1.0072
# epoch:28  d_loss:0.3012  g_loss:1.1046
# epoch:29  d_loss:0.3002  g_loss:1.1358
# epoch:30  d_loss:0.2265  g_loss:1.3928
# epoch:31  d_loss:0.2664  g_loss:1.5499
# epoch:32  d_loss:0.2279  g_loss:1.9322
# epoch:33  d_loss:0.1628  g_loss:1.9902
# epoch:34  d_loss:0.1615  g_loss:2.0397
# epoch:35  d_loss:0.3837  g_loss:1.6048
# epoch:36  d_loss:0.2563  g_loss:1.7473
# epoch:37  d_loss:0.4021  g_loss:1.5147
# epoch:38  d_loss:0.7826  g_loss:1.5268
# epoch:39  d_loss:0.7621  g_loss:1.5311
# epoch:40  d_loss:1.0477  g_loss:1.0165
# epoch:41  d_loss:0.7150  g_loss:0.9714
# epoch:42  d_loss:0.2664  g_loss:1.8954
# epoch:43  d_loss:0.0839  g_loss:2.3821
# epoch:44  d_loss:0.0467  g_loss:3.1375
# epoch:45  d_loss:0.0253  g_loss:3.4333
# epoch:46  d_loss:0.0212  g_loss:3.4244
# epoch:47  d_loss:0.0376  g_loss:3.7061
# epoch:48  d_loss:0.0158  g_loss:2.3877
# epoch:49  d_loss:0.0388  g_loss:1.6712
# epoch:50  d_loss:0.0475  g_loss:1.4050
# epoch:51  d_loss:0.2482  g_loss:2.6336
# epoch:52  d_loss:0.1228  g_loss:3.2332
# epoch:53  d_loss:0.1827  g_loss:2.4411
# epoch:54  d_loss:0.5526  g_loss:1.9133
# epoch:55  d_loss:0.6596  g_loss:1.2234
# epoch:56  d_loss:0.6903  g_loss:1.5057
# epoch:57  d_loss:0.6880  g_loss:2.5783
# epoch:58  d_loss:0.8894  g_loss:2.1999
# epoch:59  d_loss:0.9495  g_loss:1.4994
# epoch:60  d_loss:1.1724  g_loss:1.6977
# epoch:61  d_loss:0.9118  g_loss:1.6748
# epoch:62  d_loss:0.9299  g_loss:2.4117
# epoch:63  d_loss:0.7660  g_loss:2.4920
# epoch:64  d_loss:0.6763  g_loss:2.3586
# epoch:65  d_loss:0.6747  g_loss:2.3078
# epoch:66  d_loss:0.5612  g_loss:1.9686
# epoch:67  d_loss:0.3884  g_loss:2.1334
# epoch:68  d_loss:0.3489  g_loss:2.4712
# epoch:69  d_loss:0.3337  g_loss:3.0743
# epoch:70  d_loss:0.3842  g_loss:2.8130
# epoch:71  d_loss:0.2523  g_loss:2.7454
# epoch:72  d_loss:0.3974  g_loss:2.4685
# epoch:73  d_loss:0.2763  g_loss:2.2115
# epoch:74  d_loss:0.4361  g_loss:2.2220
# epoch:75  d_loss:0.4002  g_loss:2.0904
# epoch:76  d_loss:0.3597  g_loss:1.8112
# epoch:77  d_loss:0.4013  g_loss:1.8778
# epoch:78  d_loss:0.4340  g_loss:1.5288
# epoch:79  d_loss:0.4408  g_loss:1.4100
# epoch:80  d_loss:0.4998  g_loss:1.0220
# epoch:81  d_loss:0.4703  g_loss:1.0102
# epoch:82  d_loss:0.4700  g_loss:0.8693
# epoch:83  d_loss:0.5426  g_loss:0.8564
# epoch:84  d_loss:0.6097  g_loss:0.8335
# epoch:85  d_loss:0.4744  g_loss:0.7036
# epoch:86  d_loss:0.7268  g_loss:0.7155
# epoch:87  d_loss:0.6639  g_loss:0.6221
# epoch:88  d_loss:0.6349  g_loss:0.6499
# epoch:89  d_loss:0.7996  g_loss:0.7181
# epoch:90  d_loss:0.6054  g_loss:0.8455
# epoch:91  d_loss:0.6070  g_loss:1.1029
# epoch:92  d_loss:0.5522  g_loss:1.3601
# epoch:93  d_loss:0.3629  g_loss:1.8225
# epoch:94  d_loss:0.3984  g_loss:2.1020
# epoch:95  d_loss:0.2504  g_loss:2.3574
# epoch:96  d_loss:0.2633  g_loss:2.7095
# epoch:97  d_loss:0.2876  g_loss:2.3860
# epoch:98  d_loss:0.2760  g_loss:2.6305
# epoch:99  d_loss:0.2432  g_loss:2.5006
# epoch:100  d_loss:0.1613  g_loss:3.3742
# epoch:101  d_loss:0.3506  g_loss:3.0501
# epoch:102  d_loss:0.4608  g_loss:2.8918
# epoch:103  d_loss:0.3978  g_loss:3.7316
# epoch:104  d_loss:0.6851  g_loss:3.0398
# epoch:105  d_loss:0.6192  g_loss:2.1654
# epoch:106  d_loss:0.7801  g_loss:1.6323
# epoch:107  d_loss:0.7474  g_loss:1.9849
# epoch:108  d_loss:0.6142  g_loss:2.1006
# epoch:109  d_loss:0.8229  g_loss:2.0488
# epoch:110  d_loss:0.8288  g_loss:1.5693
# epoch:111  d_loss:1.0358  g_loss:1.2759
# epoch:112  d_loss:0.9505  g_loss:1.1649
# epoch:113  d_loss:0.6431  g_loss:1.3039
# epoch:114  d_loss:0.5191  g_loss:1.4973
# epoch:115  d_loss:0.6244  g_loss:1.4974
# epoch:116  d_loss:0.6128  g_loss:1.3369
# epoch:117  d_loss:0.5033  g_loss:1.2431
# epoch:118  d_loss:0.4683  g_loss:1.1680
# epoch:119  d_loss:0.4370  g_loss:1.2371
# epoch:120  d_loss:0.4806  g_loss:1.2586
# epoch:121  d_loss:0.4502  g_loss:1.1202
# epoch:122  d_loss:0.4242  g_loss:1.3017
# epoch:123  d_loss:0.4416  g_loss:1.3041
# epoch:124  d_loss:0.3379  g_loss:1.3002
# epoch:125  d_loss:0.3663  g_loss:1.2933
# epoch:126  d_loss:0.4007  g_loss:1.1994
# epoch:127  d_loss:0.3770  g_loss:1.1780
# epoch:128  d_loss:0.3460  g_loss:1.2003
# epoch:129  d_loss:0.3961  g_loss:1.4742
# epoch:130  d_loss:0.2943  g_loss:1.5660
# epoch:131  d_loss:0.3032  g_loss:1.6302
# epoch:132  d_loss:0.3159  g_loss:1.5323
# epoch:133  d_loss:0.3743  g_loss:1.6510
# epoch:134  d_loss:0.4383  g_loss:1.4274
# epoch:135  d_loss:0.3901  g_loss:1.2986
# epoch:136  d_loss:0.4272  g_loss:1.2906
# epoch:137  d_loss:0.3508  g_loss:1.4480
# epoch:138  d_loss:0.4604  g_loss:1.3378
# epoch:139  d_loss:0.6319  g_loss:1.1994
# epoch:140  d_loss:0.5601  g_loss:1.1446
# epoch:141  d_loss:0.5100  g_loss:1.2843
# epoch:142  d_loss:0.3475  g_loss:1.3964
# epoch:143  d_loss:0.4850  g_loss:1.4729
# epoch:144  d_loss:0.4913  g_loss:1.4449
# epoch:145  d_loss:0.5366  g_loss:1.2081
# epoch:146  d_loss:0.5268  g_loss:1.1910
# epoch:147  d_loss:0.5685  g_loss:1.3574
# epoch:148  d_loss:0.5127  g_loss:1.3486
# epoch:149  d_loss:0.5513  g_loss:1.4259
# epoch:150  d_loss:0.4909  g_loss:1.5731
# epoch:151  d_loss:0.4723  g_loss:1.5065
# epoch:152  d_loss:0.4468  g_loss:1.4808
# epoch:153  d_loss:0.5500  g_loss:1.4857
# epoch:154  d_loss:0.4759  g_loss:1.5497
# epoch:155  d_loss:0.4998  g_loss:1.6301
# epoch:156  d_loss:0.5342  g_loss:1.5250
# epoch:157  d_loss:0.5478  g_loss:1.4606
# epoch:158  d_loss:0.4800  g_loss:1.8674
# epoch:159  d_loss:0.4079  g_loss:2.1213
# epoch:160  d_loss:0.4226  g_loss:2.1268
# epoch:161  d_loss:0.3690  g_loss:2.3304
# epoch:162  d_loss:0.3586  g_loss:2.2100
# epoch:163  d_loss:0.4211  g_loss:1.7783
# epoch:164  d_loss:0.3736  g_loss:1.8637
# epoch:165  d_loss:0.3318  g_loss:2.0306
# epoch:166  d_loss:0.2789  g_loss:2.3406
# epoch:167  d_loss:0.3061  g_loss:2.4097
# epoch:168  d_loss:0.3159  g_loss:2.5929
# epoch:169  d_loss:0.3492  g_loss:2.6133
# epoch:170  d_loss:0.3710  g_loss:2.6726
# epoch:171  d_loss:0.4353  g_loss:2.0105
# epoch:172  d_loss:0.2606  g_loss:2.3323
# epoch:173  d_loss:0.4168  g_loss:2.1955
# epoch:174  d_loss:0.4152  g_loss:2.5948
# epoch:175  d_loss:0.4299  g_loss:2.4992
# epoch:176  d_loss:0.4639  g_loss:2.1907
# epoch:177  d_loss:0.5896  g_loss:1.7555
# epoch:178  d_loss:0.5765  g_loss:2.0837
# epoch:179  d_loss:0.4338  g_loss:1.8318
# epoch:180  d_loss:0.7440  g_loss:1.9040
# epoch:181  d_loss:0.5136  g_loss:1.9666
# epoch:182  d_loss:0.5840  g_loss:1.9727
# epoch:183  d_loss:0.6533  g_loss:1.6586
# epoch:184  d_loss:0.5600  g_loss:1.4224
# epoch:185  d_loss:0.6332  g_loss:1.4209
# epoch:186  d_loss:0.6731  g_loss:1.0639
# epoch:187  d_loss:0.5995  g_loss:1.0516
# epoch:188  d_loss:0.5078  g_loss:1.4481
# epoch:189  d_loss:0.4851  g_loss:1.7504
# epoch:190  d_loss:0.4715  g_loss:1.8366
# epoch:191  d_loss:0.5773  g_loss:1.6631
# epoch:192  d_loss:0.5393  g_loss:1.5596
# epoch:193  d_loss:0.4635  g_loss:1.4251
# epoch:194  d_loss:0.4933  g_loss:1.1242
# epoch:195  d_loss:0.3959  g_loss:1.4229
# epoch:196  d_loss:0.4293  g_loss:1.3080
# epoch:197  d_loss:0.4635  g_loss:1.6238
# epoch:198  d_loss:0.4492  g_loss:1.7040
# epoch:199  d_loss:0.4786  g_loss:1.5880
# epoch:200  d_loss:0.3461  g_loss:1.6280
# epoch:201  d_loss:0.3608  g_loss:1.7456
# epoch:202  d_loss:0.4165  g_loss:1.6986
# epoch:203  d_loss:0.3733  g_loss:1.8972
# epoch:204  d_loss:0.4121  g_loss:1.9442
# epoch:205  d_loss:0.3276  g_loss:2.2576
# epoch:206  d_loss:0.4298  g_loss:1.8117
# epoch:207  d_loss:0.4900  g_loss:1.8490
# epoch:208  d_loss:0.4457  g_loss:1.6161
# epoch:209  d_loss:0.4635  g_loss:1.5106
# epoch:210  d_loss:0.4279  g_loss:1.7947
# epoch:211  d_loss:0.4758  g_loss:1.8704
# epoch:212  d_loss:0.3853  g_loss:2.1472
# epoch:213  d_loss:0.5226  g_loss:1.9355
# epoch:214  d_loss:0.5316  g_loss:1.7433
# epoch:215  d_loss:0.4422  g_loss:1.7407
# epoch:216  d_loss:0.5219  g_loss:1.5838
# epoch:217  d_loss:0.4328  g_loss:1.6915
# epoch:218  d_loss:0.4418  g_loss:1.8827
# epoch:219  d_loss:0.4526  g_loss:2.0922
# epoch:220  d_loss:0.6146  g_loss:2.1056
# epoch:221  d_loss:0.5076  g_loss:2.0648
# epoch:222  d_loss:0.4793  g_loss:2.0762
# epoch:223  d_loss:0.5532  g_loss:1.7931
# epoch:224  d_loss:0.5195  g_loss:1.7351
# epoch:225  d_loss:0.4948  g_loss:1.6012
# epoch:226  d_loss:0.5434  g_loss:1.7451
# epoch:227  d_loss:0.4701  g_loss:1.9779
# epoch:228  d_loss:0.6247  g_loss:1.9495
# epoch:229  d_loss:0.4252  g_loss:2.0193
# epoch:230  d_loss:0.5338  g_loss:1.8978
# epoch:231  d_loss:0.6935  g_loss:1.7945
# epoch:232  d_loss:0.5491  g_loss:1.9401
# epoch:233  d_loss:0.4458  g_loss:1.8641
# epoch:234  d_loss:0.4714  g_loss:2.0303
# epoch:235  d_loss:0.4206  g_loss:1.7344
# epoch:236  d_loss:0.3838  g_loss:1.9569
# epoch:237  d_loss:0.3356  g_loss:2.2671
# epoch:238  d_loss:0.2721  g_loss:2.4582
# epoch:239  d_loss:0.4193  g_loss:2.5498
# epoch:240  d_loss:0.4182  g_loss:2.2583
# epoch:241  d_loss:0.4937  g_loss:2.9563
# epoch:242  d_loss:0.5227  g_loss:2.4725
# epoch:243  d_loss:0.3783  g_loss:2.3295
# epoch:244  d_loss:0.4055  g_loss:2.1114
# epoch:245  d_loss:0.3899  g_loss:2.1300
# epoch:246  d_loss:0.5801  g_loss:1.8775
# epoch:247  d_loss:0.7525  g_loss:1.7731
# epoch:248  d_loss:0.4216  g_loss:2.4315
# epoch:249  d_loss:0.3232  g_loss:2.4987
# epoch:250  d_loss:0.5617  g_loss:2.4713
# epoch:251  d_loss:0.4804  g_loss:1.7419
# epoch:252  d_loss:0.5362  g_loss:1.5048
# epoch:253  d_loss:0.4613  g_loss:1.6710
# epoch:254  d_loss:0.6805  g_loss:1.6801
# epoch:255  d_loss:0.5515  g_loss:1.8343
# epoch:256  d_loss:0.7120  g_loss:1.7900
# epoch:257  d_loss:0.5852  g_loss:2.0111
# epoch:258  d_loss:0.5768  g_loss:2.3516
# epoch:259  d_loss:0.7017  g_loss:1.8257
# epoch:260  d_loss:0.7075  g_loss:1.5630
# epoch:261  d_loss:0.4199  g_loss:1.5762
# epoch:262  d_loss:0.6117  g_loss:1.3179
# epoch:263  d_loss:0.4921  g_loss:1.8396
# epoch:264  d_loss:0.4792  g_loss:1.9528
# epoch:265  d_loss:0.4654  g_loss:1.7393
# epoch:266  d_loss:0.4357  g_loss:1.6955
# epoch:267  d_loss:0.6098  g_loss:1.7270
# epoch:268  d_loss:0.3401  g_loss:2.2317
# epoch:269  d_loss:0.3117  g_loss:2.5353
# epoch:270  d_loss:0.2698  g_loss:2.6486
# epoch:271  d_loss:0.3573  g_loss:2.0163
# epoch:272  d_loss:0.2867  g_loss:2.6260
# epoch:273  d_loss:0.2727  g_loss:2.4791
# epoch:274  d_loss:0.4301  g_loss:2.0509
# epoch:275  d_loss:0.4014  g_loss:2.4435
# epoch:276  d_loss:0.3616  g_loss:2.5240
# epoch:277  d_loss:0.4280  g_loss:2.1827
# epoch:278  d_loss:0.4472  g_loss:2.1705
# epoch:279  d_loss:0.4371  g_loss:2.3823
# epoch:280  d_loss:0.3691  g_loss:2.5583
# epoch:281  d_loss:0.5608  g_loss:2.2671
# epoch:282  d_loss:0.4335  g_loss:2.2996
# epoch:283  d_loss:0.4319  g_loss:2.3418
# epoch:284  d_loss:0.4613  g_loss:2.3583
# epoch:285  d_loss:0.4476  g_loss:2.0248
# epoch:286  d_loss:0.5538  g_loss:1.9153
# epoch:287  d_loss:0.5235  g_loss:2.2341
# epoch:288  d_loss:0.2908  g_loss:2.1848
# epoch:289  d_loss:0.6382  g_loss:2.3764
# epoch:290  d_loss:0.5861  g_loss:1.7620
# epoch:291  d_loss:0.4006  g_loss:1.9734
# epoch:292  d_loss:0.4035  g_loss:2.2047
# epoch:293  d_loss:0.4740  g_loss:2.2446
# epoch:294  d_loss:0.3127  g_loss:2.5082
# epoch:295  d_loss:0.4351  g_loss:2.3853
# epoch:296  d_loss:0.4506  g_loss:2.1918
# epoch:297  d_loss:0.4052  g_loss:1.9865
# epoch:298  d_loss:0.3604  g_loss:1.8828
# epoch:299  d_loss:0.3813  g_loss:2.1162
# epoch:300  d_loss:0.3904  g_loss:2.1586
# epoch:301  d_loss:0.5056  g_loss:1.9785
# epoch:302  d_loss:0.2764  g_loss:2.3211
# epoch:303  d_loss:0.3357  g_loss:2.4939
# epoch:304  d_loss:0.3687  g_loss:2.8344
# epoch:305  d_loss:0.4222  g_loss:2.3488
# epoch:306  d_loss:0.4841  g_loss:2.0326
# epoch:307  d_loss:0.3123  g_loss:1.9250
# epoch:308  d_loss:0.3400  g_loss:1.9297
# epoch:309  d_loss:0.3917  g_loss:2.0565
# epoch:310  d_loss:0.4430  g_loss:2.0049
# epoch:311  d_loss:0.3748  g_loss:1.9475
# epoch:312  d_loss:0.4417  g_loss:2.1669
# epoch:313  d_loss:0.3138  g_loss:1.8548
# epoch:314  d_loss:0.3829  g_loss:2.1669
# epoch:315  d_loss:0.3289  g_loss:2.1726
# epoch:316  d_loss:0.3713  g_loss:2.2250
# epoch:317  d_loss:0.2917  g_loss:2.5159
# epoch:318  d_loss:0.4894  g_loss:2.4771
# epoch:319  d_loss:0.4033  g_loss:2.6031
# epoch:320  d_loss:0.4124  g_loss:2.2828
# epoch:321  d_loss:0.4649  g_loss:2.0899
# epoch:322  d_loss:0.4271  g_loss:2.1999
# epoch:323  d_loss:0.3487  g_loss:2.3037
# epoch:324  d_loss:0.4184  g_loss:2.1155
# epoch:325  d_loss:0.3714  g_loss:2.4958
# epoch:326  d_loss:0.3938  g_loss:2.2378
# epoch:327  d_loss:0.4069  g_loss:2.2844
# epoch:328  d_loss:0.4839  g_loss:2.0446
# epoch:329  d_loss:0.4354  g_loss:1.9232
# epoch:330  d_loss:0.4660  g_loss:2.0538
# epoch:331  d_loss:0.4711  g_loss:2.2719
# epoch:332  d_loss:0.5901  g_loss:2.5622
# epoch:333  d_loss:0.4658  g_loss:2.5243
# epoch:334  d_loss:0.4866  g_loss:1.9827
# epoch:335  d_loss:0.6676  g_loss:2.0410
# epoch:336  d_loss:0.4773  g_loss:1.8330
# epoch:337  d_loss:0.4457  g_loss:2.1884
# epoch:338  d_loss:0.4323  g_loss:2.1093
# epoch:339  d_loss:0.4772  g_loss:2.4078
# epoch:340  d_loss:0.4466  g_loss:2.3758
# epoch:341  d_loss:0.5837  g_loss:1.6337
# epoch:342  d_loss:0.6285  g_loss:1.5701
# epoch:343  d_loss:0.3686  g_loss:2.2685
# epoch:344  d_loss:0.2753  g_loss:2.8192
# epoch:345  d_loss:0.2717  g_loss:3.1620
# epoch:346  d_loss:0.3811  g_loss:3.0052
# epoch:347  d_loss:0.2677  g_loss:2.5734
# epoch:348  d_loss:0.4693  g_loss:3.0387
# epoch:349  d_loss:0.3736  g_loss:3.0304
# epoch:350  d_loss:0.2031  g_loss:3.7422
# epoch:351  d_loss:0.2493  g_loss:3.4225
# epoch:352  d_loss:0.2600  g_loss:3.1636
# epoch:353  d_loss:0.2993  g_loss:3.0498
# epoch:354  d_loss:0.3086  g_loss:3.1433
# epoch:355  d_loss:0.3081  g_loss:3.4726
# epoch:356  d_loss:0.3715  g_loss:3.3032
# epoch:357  d_loss:0.3212  g_loss:3.2253
# epoch:358  d_loss:0.2570  g_loss:2.7797
# epoch:359  d_loss:0.5713  g_loss:2.9603
# epoch:360  d_loss:0.4105  g_loss:2.9721
# epoch:361  d_loss:0.5062  g_loss:3.3904
# epoch:362  d_loss:0.4022  g_loss:2.9753
# epoch:363  d_loss:0.5345  g_loss:2.1594
# epoch:364  d_loss:0.4999  g_loss:1.8403
# epoch:365  d_loss:0.4553  g_loss:1.7278
# epoch:366  d_loss:0.5791  g_loss:2.1199
# epoch:367  d_loss:0.4457  g_loss:2.2199
# epoch:368  d_loss:0.6003  g_loss:2.0975
# epoch:369  d_loss:0.5938  g_loss:1.9707
# epoch:370  d_loss:0.5654  g_loss:1.7275
# epoch:371  d_loss:0.4606  g_loss:1.6245
# epoch:372  d_loss:0.3937  g_loss:1.6870
# epoch:373  d_loss:0.2997  g_loss:2.3857
# epoch:374  d_loss:0.3570  g_loss:2.4159
# epoch:375  d_loss:0.3847  g_loss:2.3896
# epoch:376  d_loss:0.4688  g_loss:1.8349
# epoch:377  d_loss:0.5241  g_loss:1.9656
# epoch:378  d_loss:0.3225  g_loss:2.0636
# epoch:379  d_loss:0.3873  g_loss:2.0492
# epoch:380  d_loss:0.3427  g_loss:2.3338
# epoch:381  d_loss:0.4165  g_loss:1.9671
# epoch:382  d_loss:0.2753  g_loss:1.7768
# epoch:383  d_loss:0.3081  g_loss:2.1935
# epoch:384  d_loss:0.3066  g_loss:2.0507
# epoch:385  d_loss:0.2542  g_loss:2.5723
# epoch:386  d_loss:0.2246  g_loss:2.4820
# epoch:387  d_loss:0.2283  g_loss:2.5111
# epoch:388  d_loss:0.2817  g_loss:2.1737
# epoch:389  d_loss:0.3552  g_loss:2.1516
# epoch:390  d_loss:0.4284  g_loss:1.7845
# epoch:391  d_loss:0.3289  g_loss:2.1667
# epoch:392  d_loss:0.3675  g_loss:2.3488
# epoch:393  d_loss:0.3406  g_loss:2.3353
# epoch:394  d_loss:0.2982  g_loss:2.2849
# epoch:395  d_loss:0.3078  g_loss:2.8197
# epoch:396  d_loss:0.2825  g_loss:2.5986
# epoch:397  d_loss:0.3755  g_loss:2.0235
# epoch:398  d_loss:0.4281  g_loss:2.4725
# epoch:399  d_loss:0.3023  g_loss:2.3496
# epoch:400  d_loss:0.3357  g_loss:2.0808
# epoch:401  d_loss:0.3283  g_loss:2.1159
# epoch:402  d_loss:0.3110  g_loss:1.6967
# epoch:403  d_loss:0.3299  g_loss:2.0808
# epoch:404  d_loss:0.3728  g_loss:2.2390
# epoch:405  d_loss:0.3816  g_loss:2.2638
# epoch:406  d_loss:0.3747  g_loss:2.5532
# epoch:407  d_loss:0.2748  g_loss:2.4728
# epoch:408  d_loss:0.3837  g_loss:2.1675
# epoch:409  d_loss:0.3151  g_loss:2.0697
# epoch:410  d_loss:0.4336  g_loss:1.7555
# epoch:411  d_loss:0.3168  g_loss:1.9080
# epoch:412  d_loss:0.3698  g_loss:1.8164
# epoch:413  d_loss:0.4313  g_loss:2.0921
# epoch:414  d_loss:0.4621  g_loss:2.7851
# epoch:415  d_loss:0.3484  g_loss:3.0910
# epoch:416  d_loss:0.4669  g_loss:2.4080
# epoch:417  d_loss:0.4336  g_loss:1.7180
# epoch:418  d_loss:0.2840  g_loss:2.0656
# epoch:419  d_loss:0.2522  g_loss:2.6353
# epoch:420  d_loss:0.2654  g_loss:3.2542
# epoch:421  d_loss:0.2822  g_loss:2.7168
# epoch:422  d_loss:0.3887  g_loss:2.5813
# epoch:423  d_loss:0.3121  g_loss:2.0468
# epoch:424  d_loss:0.3638  g_loss:2.2774
# epoch:425  d_loss:0.2697  g_loss:2.5284
# epoch:426  d_loss:0.2328  g_loss:2.9203
# epoch:427  d_loss:0.3169  g_loss:3.1897
# epoch:428  d_loss:0.3537  g_loss:2.7268
# epoch:429  d_loss:0.4538  g_loss:2.0101
# epoch:430  d_loss:0.2596  g_loss:2.5653
# epoch:431  d_loss:0.2538  g_loss:2.4053
# epoch:432  d_loss:0.2226  g_loss:2.3329
# epoch:433  d_loss:0.3259  g_loss:2.0827
# epoch:434  d_loss:0.2334  g_loss:2.2924
# epoch:435  d_loss:0.2273  g_loss:2.4737
# epoch:436  d_loss:0.2752  g_loss:2.8344
# epoch:437  d_loss:0.2857  g_loss:2.3960
# epoch:438  d_loss:0.2072  g_loss:2.5983
# epoch:439  d_loss:0.1808  g_loss:2.2905
# epoch:440  d_loss:0.1457  g_loss:2.5323
# epoch:441  d_loss:0.2083  g_loss:2.7357
# epoch:442  d_loss:0.1446  g_loss:3.0875
# epoch:443  d_loss:0.2896  g_loss:3.0883
# epoch:444  d_loss:0.2875  g_loss:2.8646
# epoch:445  d_loss:0.2619  g_loss:2.8770
# epoch:446  d_loss:0.2923  g_loss:2.4035
# epoch:447  d_loss:0.2304  g_loss:3.3471
# epoch:448  d_loss:0.2298  g_loss:3.2622
# epoch:449  d_loss:0.4095  g_loss:2.5708
# epoch:450  d_loss:0.3146  g_loss:2.6911
# epoch:451  d_loss:0.5525  g_loss:2.9742
# epoch:452  d_loss:0.2804  g_loss:3.1892
# epoch:453  d_loss:0.3368  g_loss:2.3446
# epoch:454  d_loss:0.4568  g_loss:2.1943
# epoch:455  d_loss:0.5926  g_loss:1.7326
# epoch:456  d_loss:0.4147  g_loss:2.3768
# epoch:457  d_loss:0.3765  g_loss:2.9047
# epoch:458  d_loss:0.3404  g_loss:3.1881
# epoch:459  d_loss:0.3153  g_loss:2.9384
# epoch:460  d_loss:0.3654  g_loss:1.8628
# epoch:461  d_loss:0.3593  g_loss:1.9794
# epoch:462  d_loss:0.2747  g_loss:2.4129
# epoch:463  d_loss:0.2285  g_loss:3.0698
# epoch:464  d_loss:0.3126  g_loss:3.0759
# epoch:465  d_loss:0.3140  g_loss:2.2728
# epoch:466  d_loss:0.2783  g_loss:2.3275
# epoch:467  d_loss:0.2897  g_loss:2.6112
# epoch:468  d_loss:0.1245  g_loss:2.8625
# epoch:469  d_loss:0.1895  g_loss:3.1576
# epoch:470  d_loss:0.2212  g_loss:2.7668
# epoch:471  d_loss:0.2041  g_loss:2.8048
# epoch:472  d_loss:0.1403  g_loss:2.7639
# epoch:473  d_loss:0.1356  g_loss:3.1248
# epoch:474  d_loss:0.2496  g_loss:3.1021
# epoch:475  d_loss:0.1630  g_loss:2.8611
# epoch:476  d_loss:0.1488  g_loss:3.1295
# epoch:477  d_loss:0.1254  g_loss:3.1417
# epoch:478  d_loss:0.1079  g_loss:3.3327
# epoch:479  d_loss:0.1752  g_loss:3.1519
# epoch:480  d_loss:0.1547  g_loss:3.1488
# epoch:481  d_loss:0.1704  g_loss:3.1402
# epoch:482  d_loss:0.2113  g_loss:2.7564
# epoch:483  d_loss:0.1459  g_loss:2.7814
# epoch:484  d_loss:0.1610  g_loss:2.9523
# epoch:485  d_loss:0.2035  g_loss:3.3326
# epoch:486  d_loss:0.1850  g_loss:2.8637
# epoch:487  d_loss:0.2086  g_loss:3.6540
# epoch:488  d_loss:0.2554  g_loss:2.1899
# epoch:489  d_loss:0.3088  g_loss:2.4452
# epoch:490  d_loss:0.2044  g_loss:2.5520
# epoch:491  d_loss:0.2829  g_loss:2.4837
# epoch:492  d_loss:0.3349  g_loss:2.1895
# epoch:493  d_loss:0.3665  g_loss:2.3951
# epoch:494  d_loss:0.3369  g_loss:2.5860
# epoch:495  d_loss:0.2780  g_loss:3.2495
# epoch:496  d_loss:0.2400  g_loss:3.1080
# epoch:497  d_loss:0.2217  g_loss:2.6231
# epoch:498  d_loss:0.4408  g_loss:2.1638
# epoch:499  d_loss:0.5107  g_loss:2.3447
# epoch:500  d_loss:0.2694  g_loss:2.9689
# epoch:501  d_loss:0.1962  g_loss:4.2820
# epoch:502  d_loss:0.3053  g_loss:3.8411
# epoch:503  d_loss:0.2186  g_loss:2.1646
# epoch:504  d_loss:0.2576  g_loss:2.3846
# epoch:505  d_loss:0.1936  g_loss:2.7267
# epoch:506  d_loss:0.2668  g_loss:3.4543
# epoch:507  d_loss:0.1294  g_loss:3.8683
# epoch:508  d_loss:0.1296  g_loss:4.1700
# epoch:509  d_loss:0.1305  g_loss:3.6228
# epoch:510  d_loss:0.1138  g_loss:3.3974
# epoch:511  d_loss:0.0867  g_loss:4.6022
# epoch:512  d_loss:0.2018  g_loss:3.7182
# epoch:513  d_loss:0.1924  g_loss:3.9586
# epoch:514  d_loss:0.1903  g_loss:3.8738
# epoch:515  d_loss:0.1845  g_loss:3.3258
# epoch:516  d_loss:0.1456  g_loss:3.1900
# epoch:517  d_loss:0.2132  g_loss:3.0705
# epoch:518  d_loss:0.1848  g_loss:3.2870
# epoch:519  d_loss:0.1507  g_loss:2.9060
# epoch:520  d_loss:0.1168  g_loss:2.6646
# epoch:521  d_loss:0.1905  g_loss:2.7214
# epoch:522  d_loss:0.1974  g_loss:2.8184
# epoch:523  d_loss:0.2281  g_loss:3.2840
# epoch:524  d_loss:0.2054  g_loss:3.2038
# epoch:525  d_loss:0.2894  g_loss:2.7199
# epoch:526  d_loss:0.1593  g_loss:3.2183
# epoch:527  d_loss:0.2258  g_loss:3.1074
# epoch:528  d_loss:0.2719  g_loss:2.7868
# epoch:529  d_loss:0.2971  g_loss:2.7269
# epoch:530  d_loss:0.1683  g_loss:3.4497
# epoch:531  d_loss:0.2271  g_loss:2.7112
# epoch:532  d_loss:0.2102  g_loss:2.8442
# epoch:533  d_loss:0.1094  g_loss:3.5859
# epoch:534  d_loss:0.1486  g_loss:3.2260
# epoch:535  d_loss:0.1595  g_loss:2.9209
# epoch:536  d_loss:0.1433  g_loss:2.5872
# epoch:537  d_loss:0.1828  g_loss:2.9808
# epoch:538  d_loss:0.1808  g_loss:2.8179
# epoch:539  d_loss:0.1995  g_loss:2.8401
# epoch:540  d_loss:0.1707  g_loss:3.2658
# epoch:541  d_loss:0.2050  g_loss:3.3689
# epoch:542  d_loss:0.1494  g_loss:2.6766
# epoch:543  d_loss:0.2609  g_loss:2.1732
# epoch:544  d_loss:0.1242  g_loss:2.6712
# epoch:545  d_loss:0.1182  g_loss:2.7310
# epoch:546  d_loss:0.1689  g_loss:3.1268
# epoch:547  d_loss:0.1243  g_loss:3.2908
# epoch:548  d_loss:0.1564  g_loss:3.1670
# epoch:549  d_loss:0.1673  g_loss:2.5795
# epoch:550  d_loss:0.1522  g_loss:2.5434
# epoch:551  d_loss:0.1748  g_loss:2.7985
# epoch:552  d_loss:0.1880  g_loss:3.1202
# epoch:553  d_loss:0.3143  g_loss:2.7083
# epoch:554  d_loss:0.2833  g_loss:1.8902
# epoch:555  d_loss:0.2032  g_loss:2.4851
# epoch:556  d_loss:0.1691  g_loss:2.9800
# epoch:557  d_loss:0.2463  g_loss:2.9536
# epoch:558  d_loss:0.2140  g_loss:3.1222
# epoch:559  d_loss:0.2395  g_loss:2.3882
# epoch:560  d_loss:0.2446  g_loss:1.9090
# epoch:561  d_loss:0.2539  g_loss:2.3068
# epoch:562  d_loss:0.1511  g_loss:3.0255
# epoch:563  d_loss:0.1646  g_loss:2.9465
# epoch:564  d_loss:0.3709  g_loss:2.6144
# epoch:565  d_loss:0.1529  g_loss:2.0156
# epoch:566  d_loss:0.3557  g_loss:1.6622
# epoch:567  d_loss:0.1293  g_loss:2.9815
# epoch:568  d_loss:0.1261  g_loss:2.8090
# epoch:569  d_loss:0.1769  g_loss:3.1526
# epoch:570  d_loss:0.2593  g_loss:2.5543
# epoch:571  d_loss:0.2019  g_loss:2.1066
# epoch:572  d_loss:0.1277  g_loss:2.5767
# epoch:573  d_loss:0.3257  g_loss:2.7152
# epoch:574  d_loss:0.2415  g_loss:3.0942
# epoch:575  d_loss:0.2866  g_loss:1.9549
# epoch:576  d_loss:0.2628  g_loss:2.1438
# epoch:577  d_loss:0.2263  g_loss:2.3825
# epoch:578  d_loss:0.1964  g_loss:3.3383
# epoch:579  d_loss:0.1713  g_loss:3.6041
# epoch:580  d_loss:0.4706  g_loss:1.8704
# epoch:581  d_loss:0.2971  g_loss:2.2134
# epoch:582  d_loss:0.2688  g_loss:2.8820
# epoch:583  d_loss:0.4843  g_loss:2.0959
# epoch:584  d_loss:0.3036  g_loss:2.1951
# epoch:585  d_loss:0.2528  g_loss:2.2162
# epoch:586  d_loss:0.3117  g_loss:1.7200
# epoch:587  d_loss:0.2914  g_loss:2.3367
# epoch:588  d_loss:0.4068  g_loss:2.4325
# epoch:589  d_loss:0.3362  g_loss:2.1293
# epoch:590  d_loss:0.4470  g_loss:1.9221
# epoch:591  d_loss:0.2961  g_loss:2.1593
# epoch:592  d_loss:0.4875  g_loss:2.3223
# epoch:593  d_loss:0.4105  g_loss:1.8297
# epoch:594  d_loss:0.3000  g_loss:1.7460
# epoch:595  d_loss:0.5584  g_loss:1.1986
# epoch:596  d_loss:0.6829  g_loss:0.9440
# epoch:597  d_loss:0.5490  g_loss:1.0548
# epoch:598  d_loss:0.5470  g_loss:1.2017
# epoch:599  d_loss:0.5787  g_loss:1.3861
# epoch:600  d_loss:0.3606  g_loss:2.2856
# epoch:601  d_loss:0.5196  g_loss:2.5584
# epoch:602  d_loss:0.8574  g_loss:1.0991
# epoch:603  d_loss:0.7273  g_loss:0.8189
# epoch:604  d_loss:0.6483  g_loss:0.9629
# epoch:605  d_loss:0.4749  g_loss:1.8221
# epoch:606  d_loss:0.5448  g_loss:2.0982
# epoch:607  d_loss:0.7167  g_loss:1.7336
# epoch:608  d_loss:0.6206  g_loss:1.0805
# epoch:609  d_loss:0.8037  g_loss:1.1301
# epoch:610  d_loss:0.5202  g_loss:1.3422
# epoch:611  d_loss:0.4724  g_loss:2.3390
# epoch:612  d_loss:0.6924  g_loss:2.2257
# epoch:613  d_loss:0.6364  g_loss:2.1433
# epoch:614  d_loss:0.3224  g_loss:1.7038
# epoch:615  d_loss:0.5283  g_loss:1.6898
# epoch:616  d_loss:0.4415  g_loss:1.7118
# epoch:617  d_loss:0.4189  g_loss:2.3358
# epoch:618  d_loss:0.4560  g_loss:2.8541
# epoch:619  d_loss:0.6375  g_loss:2.7520
# epoch:620  d_loss:0.8778  g_loss:2.4434
# epoch:621  d_loss:0.7567  g_loss:1.5854
# epoch:622  d_loss:1.2295  g_loss:1.5165
# epoch:623  d_loss:0.9371  g_loss:1.7496
# epoch:624  d_loss:0.8135  g_loss:2.4159
# epoch:625  d_loss:0.6309  g_loss:3.0430
# epoch:626  d_loss:0.8164  g_loss:1.6258
# epoch:627  d_loss:0.6663  g_loss:1.1027
# epoch:628  d_loss:0.6762  g_loss:0.9765
# epoch:629  d_loss:0.6175  g_loss:0.8513
# epoch:630  d_loss:0.4821  g_loss:1.1066
# epoch:631  d_loss:0.3706  g_loss:2.2577
# epoch:632  d_loss:0.3693  g_loss:2.7705
# epoch:633  d_loss:0.4750  g_loss:2.9811
# epoch:634  d_loss:0.3458  g_loss:2.5601
# epoch:635  d_loss:0.3030  g_loss:2.1579
# epoch:636  d_loss:0.3047  g_loss:2.0463
# epoch:637  d_loss:0.3122  g_loss:2.1115
# epoch:638  d_loss:0.3860  g_loss:2.9801
# epoch:639  d_loss:0.5164  g_loss:2.4733
# epoch:640  d_loss:0.9838  g_loss:1.9421
# epoch:641  d_loss:1.3929  g_loss:2.1672
# epoch:642  d_loss:0.8930  g_loss:2.2605
# epoch:643  d_loss:0.5839  g_loss:3.6034
# epoch:644  d_loss:0.4468  g_loss:5.2969
# epoch:645  d_loss:0.4488  g_loss:5.7896
# epoch:646  d_loss:0.3941  g_loss:5.2435
# epoch:647  d_loss:0.3448  g_loss:4.9483
# epoch:648  d_loss:0.3307  g_loss:5.1489
# epoch:649  d_loss:0.7239  g_loss:5.1789
# epoch:650  d_loss:0.5637  g_loss:4.0393
# epoch:651  d_loss:0.5342  g_loss:3.7779
# epoch:652  d_loss:0.4637  g_loss:3.9452
# epoch:653  d_loss:0.2085  g_loss:3.6206
# epoch:654  d_loss:0.3836  g_loss:3.2006
# epoch:655  d_loss:0.2331  g_loss:2.3477
# epoch:656  d_loss:0.5049  g_loss:1.6902
# epoch:657  d_loss:0.6123  g_loss:1.5709
# epoch:658  d_loss:0.6350  g_loss:1.6942
# epoch:659  d_loss:0.5439  g_loss:2.1133
# epoch:660  d_loss:0.4117  g_loss:2.3090
# epoch:661  d_loss:0.4110  g_loss:3.6957
# epoch:662  d_loss:0.2190  g_loss:3.1672
# epoch:663  d_loss:0.2187  g_loss:3.5047
# epoch:664  d_loss:0.2989  g_loss:3.1101
# epoch:665  d_loss:0.1798  g_loss:3.3011
# epoch:666  d_loss:0.3140  g_loss:2.8845
# epoch:667  d_loss:0.3501  g_loss:2.7783
# epoch:668  d_loss:0.4823  g_loss:2.5569
# epoch:669  d_loss:0.5633  g_loss:3.1473
# epoch:670  d_loss:0.6534  g_loss:3.5748
# epoch:671  d_loss:0.8402  g_loss:3.7816
# epoch:672  d_loss:1.2608  g_loss:1.9543
# epoch:673  d_loss:1.1664  g_loss:1.2498
# epoch:674  d_loss:0.4596  g_loss:1.3400
# epoch:675  d_loss:0.5312  g_loss:2.0065
# epoch:676  d_loss:0.3302  g_loss:2.6485
# epoch:677  d_loss:0.4972  g_loss:3.3026
# epoch:678  d_loss:0.2599  g_loss:3.4422
# epoch:679  d_loss:0.3729  g_loss:3.2735
# epoch:680  d_loss:0.3462  g_loss:2.7830
# epoch:681  d_loss:0.2050  g_loss:2.9614
# epoch:682  d_loss:0.2885  g_loss:2.7731
# epoch:683  d_loss:0.3845  g_loss:2.4668
# epoch:684  d_loss:0.3436  g_loss:2.2473
# epoch:685  d_loss:0.2205  g_loss:2.5111
# epoch:686  d_loss:0.6396  g_loss:2.7114
# epoch:687  d_loss:0.4791  g_loss:2.0872
# epoch:688  d_loss:0.5996  g_loss:1.8066
# epoch:689  d_loss:0.5317  g_loss:1.9421
# epoch:690  d_loss:0.5014  g_loss:1.9197
# epoch:691  d_loss:0.5793  g_loss:1.4044
# epoch:692  d_loss:0.5298  g_loss:1.5544
# epoch:693  d_loss:0.3938  g_loss:1.6491
# epoch:694  d_loss:0.5314  g_loss:1.4501
# epoch:695  d_loss:0.4440  g_loss:1.7153
# epoch:696  d_loss:0.3678  g_loss:1.5514
# epoch:697  d_loss:0.3479  g_loss:2.1860
# epoch:698  d_loss:0.2839  g_loss:2.1606
# epoch:699  d_loss:0.2808  g_loss:2.8087
# epoch:700  d_loss:0.2811  g_loss:2.7526
# epoch:701  d_loss:0.2730  g_loss:2.5911
# epoch:702  d_loss:0.1857  g_loss:2.4614
# epoch:703  d_loss:0.3255  g_loss:1.9884
# epoch:704  d_loss:0.2861  g_loss:2.6998
# epoch:705  d_loss:0.2226  g_loss:2.6263
# epoch:706  d_loss:0.3603  g_loss:2.4698
# epoch:707  d_loss:0.5249  g_loss:2.4038
# epoch:708  d_loss:0.5936  g_loss:2.6101
# epoch:709  d_loss:0.6341  g_loss:2.5299
# epoch:710  d_loss:0.5190  g_loss:2.4983
# epoch:711  d_loss:0.3215  g_loss:2.1300
# epoch:712  d_loss:0.5487  g_loss:1.9104
# epoch:713  d_loss:0.3251  g_loss:2.1239
# epoch:714  d_loss:0.3234  g_loss:2.1329
# epoch:715  d_loss:0.2732  g_loss:1.9050
# epoch:716  d_loss:0.3256  g_loss:2.0651
# epoch:717  d_loss:0.4486  g_loss:2.0674
# epoch:718  d_loss:0.2512  g_loss:1.9813
# epoch:719  d_loss:0.2151  g_loss:2.7137
# epoch:720  d_loss:0.2472  g_loss:2.6940
# epoch:721  d_loss:0.3134  g_loss:2.7471
# epoch:722  d_loss:0.3989  g_loss:2.2916
# epoch:723  d_loss:0.2958  g_loss:2.2825
# epoch:724  d_loss:0.3309  g_loss:2.2401
# epoch:725  d_loss:0.4426  g_loss:1.7168
# epoch:726  d_loss:0.3021  g_loss:2.0498
# epoch:727  d_loss:0.4108  g_loss:1.6677
# epoch:728  d_loss:0.3795  g_loss:2.0902
# epoch:729  d_loss:0.2985  g_loss:2.4101
# epoch:730  d_loss:0.2866  g_loss:2.2750
# epoch:731  d_loss:0.4619  g_loss:2.3925
# epoch:732  d_loss:0.5501  g_loss:1.3710
# epoch:733  d_loss:0.4975  g_loss:1.5943
# epoch:734  d_loss:0.4198  g_loss:1.5179
# epoch:735  d_loss:0.3171  g_loss:1.6033
# epoch:736  d_loss:0.5386  g_loss:1.2065
# epoch:737  d_loss:0.3798  g_loss:1.5993
# epoch:738  d_loss:0.3474  g_loss:1.9446
# epoch:739  d_loss:0.5485  g_loss:1.6815
# epoch:740  d_loss:0.5051  g_loss:1.4420
# epoch:741  d_loss:0.5234  g_loss:1.4765
# epoch:742  d_loss:0.4519  g_loss:1.5992
# epoch:743  d_loss:0.3344  g_loss:1.5075
# epoch:744  d_loss:0.3255  g_loss:1.8398
# epoch:745  d_loss:0.3963  g_loss:1.7262
# epoch:746  d_loss:0.4380  g_loss:1.9055
# epoch:747  d_loss:0.3669  g_loss:1.6703
# epoch:748  d_loss:0.3166  g_loss:1.5691
# epoch:749  d_loss:0.4379  g_loss:1.5050
# epoch:750  d_loss:0.3716  g_loss:1.6409
# epoch:751  d_loss:0.4896  g_loss:1.7671
# epoch:752  d_loss:0.3783  g_loss:1.7151
# epoch:753  d_loss:0.3395  g_loss:1.8789
# epoch:754  d_loss:0.3820  g_loss:1.7028
# epoch:755  d_loss:0.3807  g_loss:1.5903
# epoch:756  d_loss:0.5738  g_loss:1.5537
# epoch:757  d_loss:0.6454  g_loss:1.3058
# epoch:758  d_loss:0.5386  g_loss:1.1349
# epoch:759  d_loss:0.6113  g_loss:0.9928
# epoch:760  d_loss:0.6256  g_loss:1.2011
# epoch:761  d_loss:0.6165  g_loss:1.2600
# epoch:762  d_loss:0.7594  g_loss:1.4526
# epoch:763  d_loss:0.6196  g_loss:1.3365
# epoch:764  d_loss:0.5995  g_loss:1.1357
# epoch:765  d_loss:0.6054  g_loss:1.2238
# epoch:766  d_loss:0.5992  g_loss:1.2475
# epoch:767  d_loss:0.4878  g_loss:1.1388
# epoch:768  d_loss:0.4432  g_loss:1.2605
# epoch:769  d_loss:0.3877  g_loss:1.4329
# epoch:770  d_loss:0.6050  g_loss:1.4625
# epoch:771  d_loss:0.5063  g_loss:1.4664
# epoch:772  d_loss:0.4679  g_loss:1.2370
# epoch:773  d_loss:0.5137  g_loss:1.6899
# epoch:774  d_loss:0.4003  g_loss:1.4501
# epoch:775  d_loss:0.5459  g_loss:1.3155
# epoch:776  d_loss:0.5329  g_loss:1.2137
# epoch:777  d_loss:0.3945  g_loss:1.6459
# epoch:778  d_loss:0.4570  g_loss:1.6461
# epoch:779  d_loss:0.4429  g_loss:1.4350
# epoch:780  d_loss:0.5213  g_loss:1.2713
# epoch:781  d_loss:0.5113  g_loss:1.3330
# epoch:782  d_loss:0.5140  g_loss:1.4761
# epoch:783  d_loss:0.6634  g_loss:0.9502
# epoch:784  d_loss:0.6261  g_loss:0.9704
# epoch:785  d_loss:0.5477  g_loss:0.9337
# epoch:786  d_loss:0.7230  g_loss:0.9508
# epoch:787  d_loss:0.7865  g_loss:0.9467
# epoch:788  d_loss:0.8631  g_loss:0.9735
# epoch:789  d_loss:0.6478  g_loss:0.9948
# epoch:790  d_loss:0.7396  g_loss:1.0220
# epoch:791  d_loss:0.7729  g_loss:1.1132
# epoch:792  d_loss:0.5787  g_loss:0.9161
# epoch:793  d_loss:0.6980  g_loss:1.0046
# epoch:794  d_loss:0.5562  g_loss:1.1667
# epoch:795  d_loss:0.6108  g_loss:1.2336
# epoch:796  d_loss:0.4795  g_loss:1.3523
# epoch:797  d_loss:0.4074  g_loss:1.5074
# epoch:798  d_loss:0.4998  g_loss:1.4515
# epoch:799  d_loss:0.4622  g_loss:1.6979
# epoch:800  d_loss:0.6368  g_loss:1.3825
# epoch:801  d_loss:0.4259  g_loss:1.8358
# epoch:802  d_loss:0.4421  g_loss:1.7930
# epoch:803  d_loss:0.4247  g_loss:1.8295
# epoch:804  d_loss:0.4092  g_loss:1.6684
# epoch:805  d_loss:0.5629  g_loss:1.4216
# epoch:806  d_loss:0.4727  g_loss:1.4707
# epoch:807  d_loss:0.3512  g_loss:1.9093
# epoch:808  d_loss:0.3798  g_loss:1.9087
# epoch:809  d_loss:0.4131  g_loss:1.9228
# epoch:810  d_loss:0.3637  g_loss:2.0851
# epoch:811  d_loss:0.4042  g_loss:1.9646
# epoch:812  d_loss:0.4275  g_loss:2.1075
# epoch:813  d_loss:0.3992  g_loss:1.7407
# epoch:814  d_loss:0.4478  g_loss:1.6112
# epoch:815  d_loss:0.4687  g_loss:1.3499
# epoch:816  d_loss:0.4176  g_loss:2.1695
# epoch:817  d_loss:0.4240  g_loss:2.2872
# epoch:818  d_loss:0.3441  g_loss:2.5333
# epoch:819  d_loss:0.4405  g_loss:2.0941
# epoch:820  d_loss:0.4531  g_loss:2.4822
# epoch:821  d_loss:0.4326  g_loss:1.6431
# epoch:822  d_loss:0.5391  g_loss:1.3809
# epoch:823  d_loss:0.6304  g_loss:1.4332
# epoch:824  d_loss:0.5547  g_loss:2.1854
# epoch:825  d_loss:0.6133  g_loss:1.8007
# epoch:826  d_loss:0.7440  g_loss:1.6774
# epoch:827  d_loss:0.4127  g_loss:1.5216
# epoch:828  d_loss:0.4555  g_loss:1.6243
# epoch:829  d_loss:0.5525  g_loss:1.4715
# epoch:830  d_loss:0.4471  g_loss:1.6642
# epoch:831  d_loss:0.4840  g_loss:1.6607
# epoch:832  d_loss:0.4217  g_loss:1.7679
# epoch:833  d_loss:0.3807  g_loss:1.6845
# epoch:834  d_loss:0.6329  g_loss:1.5731
# epoch:835  d_loss:0.3670  g_loss:1.8724
# epoch:836  d_loss:0.5681  g_loss:1.6305
# epoch:837  d_loss:0.4964  g_loss:1.6084
# epoch:838  d_loss:0.5219  g_loss:1.8382
# epoch:839  d_loss:0.4459  g_loss:1.7582
# epoch:840  d_loss:0.5408  g_loss:1.3594
# epoch:841  d_loss:0.7123  g_loss:1.2006
# epoch:842  d_loss:0.5859  g_loss:1.2806
# epoch:843  d_loss:0.4291  g_loss:1.5746
# epoch:844  d_loss:0.5267  g_loss:1.6835
# epoch:845  d_loss:0.4453  g_loss:2.3364
# epoch:846  d_loss:0.4940  g_loss:1.7235
# epoch:847  d_loss:0.4886  g_loss:1.5732
# epoch:848  d_loss:0.5168  g_loss:1.5012
# epoch:849  d_loss:0.4073  g_loss:1.4787
# epoch:850  d_loss:0.4704  g_loss:1.7792
# epoch:851  d_loss:0.3965  g_loss:1.8654
# epoch:852  d_loss:0.3837  g_loss:1.6333
# epoch:853  d_loss:0.3940  g_loss:2.0556
# epoch:854  d_loss:0.4241  g_loss:1.9888
# epoch:855  d_loss:0.2808  g_loss:2.0184
# epoch:856  d_loss:0.3786  g_loss:1.6397
# epoch:857  d_loss:0.3212  g_loss:1.7789
# epoch:858  d_loss:0.5567  g_loss:1.7726
# epoch:859  d_loss:0.6389  g_loss:1.3936
# epoch:860  d_loss:0.4456  g_loss:1.3767
# epoch:861  d_loss:0.4718  g_loss:1.5435
# epoch:862  d_loss:0.6087  g_loss:1.6005
# epoch:863  d_loss:0.4396  g_loss:1.9290
# epoch:864  d_loss:0.4728  g_loss:1.7786
# epoch:865  d_loss:0.4645  g_loss:1.9203
# epoch:866  d_loss:0.4306  g_loss:1.5422
# epoch:867  d_loss:0.4464  g_loss:1.5139
# epoch:868  d_loss:0.3996  g_loss:1.8305
# epoch:869  d_loss:0.5026  g_loss:1.4903
# epoch:870  d_loss:0.4042  g_loss:2.0717
# epoch:871  d_loss:0.4269  g_loss:1.9224
# epoch:872  d_loss:0.4649  g_loss:1.8317
# epoch:873  d_loss:0.3661  g_loss:1.6957
# epoch:874  d_loss:0.3782  g_loss:1.7207
# epoch:875  d_loss:0.3015  g_loss:1.9578
# epoch:876  d_loss:0.3540  g_loss:1.9498
# epoch:877  d_loss:0.3860  g_loss:1.8780
# epoch:878  d_loss:0.3422  g_loss:2.3360
# epoch:879  d_loss:0.4265  g_loss:1.8075
# epoch:880  d_loss:0.5344  g_loss:1.6336
# epoch:881  d_loss:0.4980  g_loss:1.4547
# epoch:882  d_loss:0.4256  g_loss:1.8956
# epoch:883  d_loss:0.3576  g_loss:2.1667
# epoch:884  d_loss:0.4249  g_loss:2.0087
# epoch:885  d_loss:0.3866  g_loss:1.9367
# epoch:886  d_loss:0.4200  g_loss:1.9141
# epoch:887  d_loss:0.3738  g_loss:1.8451
# epoch:888  d_loss:0.5646  g_loss:1.8053
# epoch:889  d_loss:0.4664  g_loss:2.2432
# epoch:890  d_loss:0.5675  g_loss:1.6911
# epoch:891  d_loss:0.4070  g_loss:1.7396
# epoch:892  d_loss:0.4082  g_loss:1.6960
# epoch:893  d_loss:0.4237  g_loss:1.5893
# epoch:894  d_loss:0.5629  g_loss:1.4724
# epoch:895  d_loss:0.4718  g_loss:1.9152
# epoch:896  d_loss:0.4797  g_loss:1.8165
# epoch:897  d_loss:0.5536  g_loss:1.5760
# epoch:898  d_loss:0.3203  g_loss:1.8763
# epoch:899  d_loss:0.4349  g_loss:1.6474
# epoch:900  d_loss:0.4474  g_loss:1.5077
# epoch:901  d_loss:0.6410  g_loss:1.4581
# epoch:902  d_loss:0.4122  g_loss:1.6549
# epoch:903  d_loss:0.4343  g_loss:1.7630
# epoch:904  d_loss:0.3825  g_loss:2.0750
# epoch:905  d_loss:0.4911  g_loss:1.8158
# epoch:906  d_loss:0.4122  g_loss:1.7426
# epoch:907  d_loss:0.4139  g_loss:1.8897
# epoch:908  d_loss:0.4523  g_loss:1.9230
# epoch:909  d_loss:0.4275  g_loss:1.6220
# epoch:910  d_loss:0.5154  g_loss:1.8624
# epoch:911  d_loss:0.3823  g_loss:1.8377
# epoch:912  d_loss:0.2823  g_loss:2.3796
# epoch:913  d_loss:0.3276  g_loss:2.3492
# epoch:914  d_loss:0.3498  g_loss:2.1682
# epoch:915  d_loss:0.2703  g_loss:2.1178
# epoch:916  d_loss:0.3095  g_loss:2.2731
# epoch:917  d_loss:0.3350  g_loss:2.1975
# epoch:918  d_loss:0.3827  g_loss:2.1273
# epoch:919  d_loss:0.2912  g_loss:2.5131
# epoch:920  d_loss:0.3943  g_loss:2.3749
# epoch:921  d_loss:0.4103  g_loss:2.1455
# epoch:922  d_loss:0.3405  g_loss:2.4027
# epoch:923  d_loss:0.4139  g_loss:2.0949
# epoch:924  d_loss:0.3779  g_loss:1.9218
# epoch:925  d_loss:0.4292  g_loss:2.1964
# epoch:926  d_loss:0.3701  g_loss:2.0947
# epoch:927  d_loss:0.5439  g_loss:1.5287
# epoch:928  d_loss:0.4099  g_loss:1.8055
# epoch:929  d_loss:0.4754  g_loss:1.7850
# epoch:930  d_loss:0.7011  g_loss:1.7023
# epoch:931  d_loss:0.4522  g_loss:1.7400
# epoch:932  d_loss:0.5352  g_loss:1.4981
# epoch:933  d_loss:0.5791  g_loss:1.1518
# epoch:934  d_loss:0.4852  g_loss:1.2355
# epoch:935  d_loss:0.5203  g_loss:1.3524
# epoch:936  d_loss:0.6613  g_loss:1.4635
# epoch:937  d_loss:0.6036  g_loss:1.6814
# epoch:938  d_loss:0.6427  g_loss:1.6576
# epoch:939  d_loss:0.5284  g_loss:1.3428
# epoch:940  d_loss:0.6890  g_loss:1.1108
# epoch:941  d_loss:0.4699  g_loss:1.2993
# epoch:942  d_loss:0.5756  g_loss:1.4323
# epoch:943  d_loss:0.5229  g_loss:1.7867
# epoch:944  d_loss:0.4687  g_loss:2.0361
# epoch:945  d_loss:0.4444  g_loss:2.3981
# epoch:946  d_loss:0.4729  g_loss:2.0365
# epoch:947  d_loss:0.5509  g_loss:1.4010
# epoch:948  d_loss:0.5077  g_loss:1.3332
# epoch:949  d_loss:0.3580  g_loss:1.6050
# epoch:950  d_loss:0.4684  g_loss:2.0186
# epoch:951  d_loss:0.3073  g_loss:1.7412
# epoch:952  d_loss:0.3301  g_loss:1.8329
# epoch:953  d_loss:0.3087  g_loss:1.8541
# epoch:954  d_loss:0.3437  g_loss:2.0589
# epoch:955  d_loss:0.3995  g_loss:1.9205
# epoch:956  d_loss:0.2950  g_loss:2.1855
# epoch:957  d_loss:0.4508  g_loss:1.7288
# epoch:958  d_loss:0.3467  g_loss:1.7756
# epoch:959  d_loss:0.3036  g_loss:1.7331
# epoch:960  d_loss:0.3323  g_loss:1.7510
# epoch:961  d_loss:0.4214  g_loss:1.7124
# epoch:962  d_loss:0.3310  g_loss:2.1496
# epoch:963  d_loss:0.3031  g_loss:2.2115
# epoch:964  d_loss:0.4205  g_loss:1.9284
# epoch:965  d_loss:0.5056  g_loss:2.0674
# epoch:966  d_loss:0.4316  g_loss:1.7379
# epoch:967  d_loss:0.3919  g_loss:1.8582
# epoch:968  d_loss:0.5017  g_loss:1.5487
# epoch:969  d_loss:0.5275  g_loss:1.5664
# epoch:970  d_loss:0.6384  g_loss:1.6221
# epoch:971  d_loss:0.5592  g_loss:1.6335
# epoch:972  d_loss:0.4811  g_loss:1.9608
# epoch:973  d_loss:0.4709  g_loss:2.0358
# epoch:974  d_loss:0.5836  g_loss:1.8719
# epoch:975  d_loss:0.5622  g_loss:1.5463
# epoch:976  d_loss:0.7352  g_loss:1.1564
# epoch:977  d_loss:0.6513  g_loss:1.0465
# epoch:978  d_loss:0.6465  g_loss:1.2401
# epoch:979  d_loss:0.6031  g_loss:1.5754
# epoch:980  d_loss:0.5131  g_loss:1.6530
# epoch:981  d_loss:0.4574  g_loss:2.0183
# epoch:982  d_loss:0.4740  g_loss:1.6337
# epoch:983  d_loss:0.5918  g_loss:1.3976
# epoch:984  d_loss:0.5789  g_loss:1.2006
# epoch:985  d_loss:0.4899  g_loss:1.2711
# epoch:986  d_loss:0.4290  g_loss:1.3589
# epoch:987  d_loss:0.3992  g_loss:1.7614
# epoch:988  d_loss:0.4840  g_loss:1.5527
# epoch:989  d_loss:0.3426  g_loss:1.8482
# epoch:990  d_loss:0.4775  g_loss:1.6201
# epoch:991  d_loss:0.3631  g_loss:1.8953
# epoch:992  d_loss:0.3597  g_loss:2.0534
# epoch:993  d_loss:0.2534  g_loss:2.2920
# epoch:994  d_loss:0.2976  g_loss:2.1784
# epoch:995  d_loss:0.3948  g_loss:2.5310
# epoch:996  d_loss:0.3548  g_loss:2.1056
# epoch:997  d_loss:0.4372  g_loss:1.8021
# epoch:998  d_loss:0.3614  g_loss:1.9879
# epoch:999  d_loss:0.2813  g_loss:2.2419
# epoch:1000  d_loss:0.3511  g_loss:1.8788
# epoch:1001  d_loss:0.2687  g_loss:2.2885
# epoch:1002  d_loss:0.3723  g_loss:2.2635
# epoch:1003  d_loss:0.3920  g_loss:2.1680
# epoch:1004  d_loss:0.2696  g_loss:2.3683
# epoch:1005  d_loss:0.3804  g_loss:2.0329
# epoch:1006  d_loss:0.4176  g_loss:1.8277
# epoch:1007  d_loss:0.5421  g_loss:1.8681
# epoch:1008  d_loss:0.5967  g_loss:1.2885
# epoch:1009  d_loss:0.3478  g_loss:2.7480
# epoch:1010  d_loss:0.6170  g_loss:2.5294
# epoch:1011  d_loss:0.5104  g_loss:2.1759
# epoch:1012  d_loss:0.7033  g_loss:1.6338
# epoch:1013  d_loss:0.4556  g_loss:1.4760
# epoch:1014  d_loss:0.5084  g_loss:1.4387
# epoch:1015  d_loss:0.6052  g_loss:1.7641
# epoch:1016  d_loss:0.5990  g_loss:1.9973
# epoch:1017  d_loss:0.4831  g_loss:2.4606
# epoch:1018  d_loss:0.6383  g_loss:2.0688
# epoch:1019  d_loss:0.5744  g_loss:1.8187
# epoch:1020  d_loss:0.4351  g_loss:1.8443
# epoch:1021  d_loss:0.2835  g_loss:1.8328
# epoch:1022  d_loss:0.5472  g_loss:2.1834
# epoch:1023  d_loss:0.4099  g_loss:1.8894
# epoch:1024  d_loss:0.3749  g_loss:2.5067
# epoch:1025  d_loss:0.3681  g_loss:2.7688
# epoch:1026  d_loss:0.3640  g_loss:2.6417
# epoch:1027  d_loss:0.2737  g_loss:2.5893
# epoch:1028  d_loss:0.3498  g_loss:2.4623
# epoch:1029  d_loss:0.3970  g_loss:1.9423
# epoch:1030  d_loss:0.3775  g_loss:2.3724
# epoch:1031  d_loss:0.4238  g_loss:2.3827
# epoch:1032  d_loss:0.4828  g_loss:1.9980
# epoch:1033  d_loss:0.4029  g_loss:2.2855
# epoch:1034  d_loss:0.4269  g_loss:1.8653
# epoch:1035  d_loss:0.3926  g_loss:2.0181
# epoch:1036  d_loss:0.4272  g_loss:1.5561
# epoch:1037  d_loss:0.6539  g_loss:1.1190
# epoch:1038  d_loss:0.5792  g_loss:1.6677
# epoch:1039  d_loss:0.4223  g_loss:1.8990
# epoch:1040  d_loss:0.5914  g_loss:1.9649
# epoch:1041  d_loss:0.5043  g_loss:1.8950
# epoch:1042  d_loss:0.6128  g_loss:1.7921
# epoch:1043  d_loss:0.3765  g_loss:1.8801
# epoch:1044  d_loss:0.3967  g_loss:1.7886
# epoch:1045  d_loss:0.4121  g_loss:2.1163
# epoch:1046  d_loss:0.4274  g_loss:2.2875
# epoch:1047  d_loss:0.3712  g_loss:2.4193
# epoch:1048  d_loss:0.2848  g_loss:2.3975
# epoch:1049  d_loss:0.2582  g_loss:2.6503
# epoch:1050  d_loss:0.2313  g_loss:2.4672
# epoch:1051  d_loss:0.3666  g_loss:2.1636
# epoch:1052  d_loss:0.2455  g_loss:2.3207
# epoch:1053  d_loss:0.2528  g_loss:2.7588
# epoch:1054  d_loss:0.2488  g_loss:2.5586
# epoch:1055  d_loss:0.2514  g_loss:2.5691
# epoch:1056  d_loss:0.2978  g_loss:2.4834
# epoch:1057  d_loss:0.2275  g_loss:2.3181
# epoch:1058  d_loss:0.2709  g_loss:2.8484
# epoch:1059  d_loss:0.3092  g_loss:2.7185
# epoch:1060  d_loss:0.3719  g_loss:2.6064
# epoch:1061  d_loss:0.3871  g_loss:2.5741
# epoch:1062  d_loss:0.4215  g_loss:2.0301
# epoch:1063  d_loss:0.4031  g_loss:2.3420
# epoch:1064  d_loss:0.3162  g_loss:1.9827
# epoch:1065  d_loss:0.3079  g_loss:2.3181
# epoch:1066  d_loss:0.3647  g_loss:1.6485
# epoch:1067  d_loss:0.5393  g_loss:1.5945
# epoch:1068  d_loss:0.2986  g_loss:2.4221
# epoch:1069  d_loss:0.3431  g_loss:2.1149
# epoch:1070  d_loss:0.4580  g_loss:1.9549
# epoch:1071  d_loss:0.2952  g_loss:2.2227
# epoch:1072  d_loss:0.5780  g_loss:1.5828
# epoch:1073  d_loss:0.3699  g_loss:1.6900
# epoch:1074  d_loss:0.3951  g_loss:1.7827
# epoch:1075  d_loss:0.4383  g_loss:1.8541
# epoch:1076  d_loss:0.5638  g_loss:2.2503
# epoch:1077  d_loss:0.3693  g_loss:1.7163
# epoch:1078  d_loss:0.3624  g_loss:1.8381
# epoch:1079  d_loss:0.4166  g_loss:2.2012
# epoch:1080  d_loss:0.3930  g_loss:1.8872
# epoch:1081  d_loss:0.3159  g_loss:2.3299
# epoch:1082  d_loss:0.4111  g_loss:1.8394
# epoch:1083  d_loss:0.5003  g_loss:1.6874
# epoch:1084  d_loss:0.5111  g_loss:1.8094
# epoch:1085  d_loss:0.4360  g_loss:2.1366
# epoch:1086  d_loss:0.5825  g_loss:2.1162
# epoch:1087  d_loss:0.4367  g_loss:2.4237
# epoch:1088  d_loss:0.4708  g_loss:2.2977
# epoch:1089  d_loss:0.4178  g_loss:2.2033
# epoch:1090  d_loss:0.3829  g_loss:1.9984
# epoch:1091  d_loss:0.3952  g_loss:2.0920
# epoch:1092  d_loss:0.2941  g_loss:2.4141
# epoch:1093  d_loss:0.3336  g_loss:2.3514
# epoch:1094  d_loss:0.3267  g_loss:2.5012
# epoch:1095  d_loss:0.3784  g_loss:2.6625
# epoch:1096  d_loss:0.3782  g_loss:2.6752
# epoch:1097  d_loss:0.3411  g_loss:2.7496
# epoch:1098  d_loss:0.4276  g_loss:2.3927
# epoch:1099  d_loss:0.3245  g_loss:2.5441
# epoch:1100  d_loss:0.3391  g_loss:2.3199
# epoch:1101  d_loss:0.3565  g_loss:2.3534
# epoch:1102  d_loss:0.4286  g_loss:2.4334
# epoch:1103  d_loss:0.5125  g_loss:1.9621
# epoch:1104  d_loss:0.4571  g_loss:1.9040
# epoch:1105  d_loss:0.3235  g_loss:2.4278
# epoch:1106  d_loss:0.5403  g_loss:1.7603
# epoch:1107  d_loss:0.5959  g_loss:1.9945
# epoch:1108  d_loss:0.3133  g_loss:1.9699
# epoch:1109  d_loss:0.4250  g_loss:1.9577
# epoch:1110  d_loss:0.6145  g_loss:1.7508
# epoch:1111  d_loss:0.3747  g_loss:1.8401
# epoch:1112  d_loss:0.2980  g_loss:2.0091
# epoch:1113  d_loss:0.4990  g_loss:2.5338
# epoch:1114  d_loss:0.4483  g_loss:2.2308
# epoch:1115  d_loss:0.4268  g_loss:1.7207
# epoch:1116  d_loss:0.4364  g_loss:1.7635
# epoch:1117  d_loss:0.2443  g_loss:2.1557
# epoch:1118  d_loss:0.2766  g_loss:2.0262
# epoch:1119  d_loss:0.2328  g_loss:3.0369
# epoch:1120  d_loss:0.2263  g_loss:3.1780
# epoch:1121  d_loss:0.2214  g_loss:3.2756
# epoch:1122  d_loss:0.2392  g_loss:2.8763
# epoch:1123  d_loss:0.1945  g_loss:2.5149
# epoch:1124  d_loss:0.3848  g_loss:1.9330
# epoch:1125  d_loss:0.2741  g_loss:2.2122
# epoch:1126  d_loss:0.2053  g_loss:2.5191
# epoch:1127  d_loss:0.2123  g_loss:2.7417
# epoch:1128  d_loss:0.1835  g_loss:2.9789
# epoch:1129  d_loss:0.1682  g_loss:3.1387
# epoch:1130  d_loss:0.2611  g_loss:2.1500
# epoch:1131  d_loss:0.3450  g_loss:2.0073
# epoch:1132  d_loss:0.2697  g_loss:1.9727
# epoch:1133  d_loss:0.2399  g_loss:2.1263
# epoch:1134  d_loss:0.2871  g_loss:2.2496
# epoch:1135  d_loss:0.3569  g_loss:2.2565
# epoch:1136  d_loss:0.4790  g_loss:2.5217
# epoch:1137  d_loss:0.4558  g_loss:2.3171
# epoch:1138  d_loss:0.4423  g_loss:1.9634
# epoch:1139  d_loss:0.5136  g_loss:1.9559
# epoch:1140  d_loss:0.4186  g_loss:2.2829
# epoch:1141  d_loss:0.3904  g_loss:2.1641
# epoch:1142  d_loss:0.3453  g_loss:2.6800
# epoch:1143  d_loss:0.2934  g_loss:2.5393
# epoch:1144  d_loss:0.4618  g_loss:2.2388
# epoch:1145  d_loss:0.3577  g_loss:2.7077
# epoch:1146  d_loss:0.4031  g_loss:2.2588
# epoch:1147  d_loss:0.3209  g_loss:2.8552
# epoch:1148  d_loss:0.3991  g_loss:2.1899
# epoch:1149  d_loss:0.4801  g_loss:1.8246
# epoch:1150  d_loss:0.4561  g_loss:2.1491
# epoch:1151  d_loss:0.3484  g_loss:2.3161
# epoch:1152  d_loss:0.3811  g_loss:2.1580
# epoch:1153  d_loss:0.3445  g_loss:2.6794
# epoch:1154  d_loss:0.4684  g_loss:2.1433
# epoch:1155  d_loss:0.5433  g_loss:1.8705
# epoch:1156  d_loss:0.5316  g_loss:1.6880
# epoch:1157  d_loss:0.3476  g_loss:1.9898
# epoch:1158  d_loss:0.4437  g_loss:1.9225
# epoch:1159  d_loss:0.4550  g_loss:1.7768
# epoch:1160  d_loss:0.2609  g_loss:2.0055
# epoch:1161  d_loss:0.3270  g_loss:2.4273
# epoch:1162  d_loss:0.4895  g_loss:2.0921
# epoch:1163  d_loss:0.4865  g_loss:1.5877
# epoch:1164  d_loss:0.3879  g_loss:1.8488
# epoch:1165  d_loss:0.3507  g_loss:2.1669
# epoch:1166  d_loss:0.4482  g_loss:1.7251
# epoch:1167  d_loss:0.3810  g_loss:2.1311
# epoch:1168  d_loss:0.2734  g_loss:2.0743
# epoch:1169  d_loss:0.4676  g_loss:1.9599
# epoch:1170  d_loss:0.4943  g_loss:1.9425
# epoch:1171  d_loss:0.4891  g_loss:1.5382
# epoch:1172  d_loss:0.4593  g_loss:1.5844
# epoch:1173  d_loss:0.4219  g_loss:1.7723
# epoch:1174  d_loss:0.5583  g_loss:1.7141
# epoch:1175  d_loss:0.4764  g_loss:2.2490
# epoch:1176  d_loss:0.6367  g_loss:1.8680
# epoch:1177  d_loss:0.5323  g_loss:1.6708
# epoch:1178  d_loss:0.5989  g_loss:1.4573
# ...
# epoch:3620  d_loss:0.3952  g_loss:2.2508
# epoch:3621  d_loss:0.3966  g_loss:1.8120
# epoch:3622  d_loss:0.5056  g_loss:1.7623
# epoch:3623  d_loss:0.2852  g_loss:2.0505
# epoch:3624  d_loss:0.3079  g_loss:1.8178
# epoch:3625  d_loss:0.4879  g_loss:2.2031
# epoch:3626  d_loss:0.3354  g_loss:1.7084
# epoch:3627  d_loss:0.4838  g_loss:1.9805
# epoch:3628  d_loss:0.4698  g_loss:1.8110
# epoch:3629  d_loss:0.4627  g_loss:2.0403
# epoch:3630  d_loss:0.4336  g_loss:2.0581
# epoch:3631  d_loss:0.4503  g_loss:2.1101
# epoch:3632  d_loss:0.3368  g_loss:1.9057
# epoch:3633  d_loss:0.5825  g_loss:1.6881
# epoch:3634  d_loss:0.5209  g_loss:1.8194
# epoch:3635  d_loss:0.4893  g_loss:1.8785
# epoch:3636  d_loss:0.6717  g_loss:1.6333
# epoch:3637  d_loss:0.5508  g_loss:1.6972
# epoch:3638  d_loss:0.4388  g_loss:1.6762
# epoch:3639  d_loss:0.5640  g_loss:1.8104
# epoch:3640  d_loss:0.6932  g_loss:1.4898
# epoch:3641  d_loss:0.5078  g_loss:1.4974
# epoch:3642  d_loss:0.5673  g_loss:1.1708
# epoch:3643  d_loss:0.4886  g_loss:1.6387
# epoch:3644  d_loss:0.5698  g_loss:1.6548
# epoch:3645  d_loss:0.4242  g_loss:2.2900
# epoch:3646  d_loss:0.4419  g_loss:2.0806
# epoch:3647  d_loss:0.4636  g_loss:1.8882
# epoch:3648  d_loss:0.5087  g_loss:1.6399
# epoch:3649  d_loss:0.5889  g_loss:1.6461
# epoch:3650  d_loss:0.3091  g_loss:1.8025
# epoch:3651  d_loss:0.3915  g_loss:1.5195
# epoch:3652  d_loss:0.4563  g_loss:1.6669
# epoch:3653  d_loss:0.3716  g_loss:1.9461
# epoch:3654  d_loss:0.5193  g_loss:1.6320
# epoch:3655  d_loss:0.5608  g_loss:2.0081
# epoch:3656  d_loss:0.4981  g_loss:2.0664
# epoch:3657  d_loss:0.4429  g_loss:1.6394
# epoch:3658  d_loss:0.5403  g_loss:1.6139
# epoch:3659  d_loss:0.3895  g_loss:1.7900
# epoch:3660  d_loss:0.4710  g_loss:1.6429
# epoch:3661  d_loss:0.4137  g_loss:2.0736
# epoch:3662  d_loss:0.4260  g_loss:2.0327
# epoch:3663  d_loss:0.2879  g_loss:2.3244
# epoch:3664  d_loss:0.4702  g_loss:1.7334
# epoch:3665  d_loss:0.5441  g_loss:1.5942
# epoch:3666  d_loss:0.5102  g_loss:1.6432
# epoch:3667  d_loss:0.5345  g_loss:1.9930
# epoch:3668  d_loss:0.4915  g_loss:1.7152
# epoch:3669  d_loss:0.3696  g_loss:2.5375
# epoch:3670  d_loss:0.4573  g_loss:2.4696
# epoch:3671  d_loss:0.3786  g_loss:2.1312
# epoch:3672  d_loss:0.4351  g_loss:1.7811
# epoch:3673  d_loss:0.4924  g_loss:1.6185
# epoch:3674  d_loss:0.4529  g_loss:1.5157
# epoch:3675  d_loss:0.3490  g_loss:1.9731
# epoch:3676  d_loss:0.6271  g_loss:2.0973
# epoch:3677  d_loss:0.5098  g_loss:1.8000
# epoch:3678  d_loss:0.5340  g_loss:1.1658
# epoch:3679  d_loss:0.5432  g_loss:1.2614
# epoch:3680  d_loss:0.3079  g_loss:1.7254
# epoch:3681  d_loss:0.3919  g_loss:1.9541
# epoch:3682  d_loss:0.5664  g_loss:1.5562
# epoch:3683  d_loss:0.6276  g_loss:1.6616
# epoch:3684  d_loss:0.4991  g_loss:2.0957
# epoch:3685  d_loss:0.4551  g_loss:1.7571
# epoch:3686  d_loss:0.3992  g_loss:1.9388
# epoch:3687  d_loss:0.5201  g_loss:1.6796
# epoch:3688  d_loss:0.4582  g_loss:1.5479
# epoch:3689  d_loss:0.4568  g_loss:1.7315
# epoch:3690  d_loss:0.4224  g_loss:1.5647
# epoch:3691  d_loss:0.4222  g_loss:1.9732
# epoch:3692  d_loss:0.4018  g_loss:2.0479
# epoch:3693  d_loss:0.4623  g_loss:1.7587
# epoch:3694  d_loss:0.4041  g_loss:1.6640
# epoch:3695  d_loss:0.5057  g_loss:1.6048
# epoch:3696  d_loss:0.5399  g_loss:1.3065
# epoch:3697  d_loss:0.3655  g_loss:1.6729
# epoch:3698  d_loss:0.5011  g_loss:1.5485
# epoch:3699  d_loss:0.4612  g_loss:1.9266
# epoch:3700  d_loss:0.4542  g_loss:1.9890
# epoch:3701  d_loss:0.3984  g_loss:2.1968
# epoch:3702  d_loss:0.6249  g_loss:1.8963
# epoch:3703  d_loss:0.5843  g_loss:1.4529
# epoch:3704  d_loss:0.6147  g_loss:1.1436
# epoch:3705  d_loss:0.3863  g_loss:1.5371
# epoch:3706  d_loss:0.4871  g_loss:2.0168
# epoch:3707  d_loss:0.5573  g_loss:1.7517
# epoch:3708  d_loss:0.4559  g_loss:1.8612
# epoch:3709  d_loss:0.4178  g_loss:1.8167
# epoch:3710  d_loss:0.5257  g_loss:1.7328
# epoch:3711  d_loss:0.4964  g_loss:1.6500
# epoch:3712  d_loss:0.4041  g_loss:2.1527
# epoch:3713  d_loss:0.5708  g_loss:1.6679
# epoch:3714  d_loss:0.4833  g_loss:1.9013
# epoch:3715  d_loss:0.4454  g_loss:1.7434
# epoch:3716  d_loss:0.6740  g_loss:2.0030
# epoch:3717  d_loss:0.5394  g_loss:1.7185
# epoch:3718  d_loss:0.3789  g_loss:1.7379
# epoch:3719  d_loss:0.4528  g_loss:2.0905
# epoch:3720  d_loss:0.4681  g_loss:1.8215
# epoch:3721  d_loss:0.5034  g_loss:1.5592
# epoch:3722  d_loss:0.5629  g_loss:1.8070
# epoch:3723  d_loss:0.6099  g_loss:1.4280
# epoch:3724  d_loss:0.5086  g_loss:1.8865
# epoch:3725  d_loss:0.6135  g_loss:1.8592
# epoch:3726  d_loss:0.4997  g_loss:2.0049
# epoch:3727  d_loss:0.5993  g_loss:1.6708
# epoch:3728  d_loss:0.4407  g_loss:1.8724
# epoch:3729  d_loss:0.4994  g_loss:1.7022
# epoch:3730  d_loss:0.4907  g_loss:1.5104
# epoch:3731  d_loss:0.5658  g_loss:1.6973
# epoch:3732  d_loss:0.4391  g_loss:1.8416
# epoch:3733  d_loss:0.4871  g_loss:1.7593
# epoch:3734  d_loss:0.3234  g_loss:2.2027
# epoch:3735  d_loss:0.3972  g_loss:2.1608
# epoch:3736  d_loss:0.4724  g_loss:1.9793
# epoch:3737  d_loss:0.4157  g_loss:2.1701
# epoch:3738  d_loss:0.4317  g_loss:1.8886
# epoch:3739  d_loss:0.4328  g_loss:1.9261
# epoch:3740  d_loss:0.4820  g_loss:1.8864
# epoch:3741  d_loss:0.4678  g_loss:1.8463
# epoch:3742  d_loss:0.3920  g_loss:2.2815
# epoch:3743  d_loss:0.3462  g_loss:1.9388
# epoch:3744  d_loss:0.3847  g_loss:2.0532
# epoch:3745  d_loss:0.4101  g_loss:1.7977
# epoch:3746  d_loss:0.3866  g_loss:1.8138
# epoch:3747  d_loss:0.4137  g_loss:1.4689
# epoch:3748  d_loss:0.4692  g_loss:1.7040
# epoch:3749  d_loss:0.6567  g_loss:1.7109
# epoch:3750  d_loss:0.5866  g_loss:2.0658
# epoch:3751  d_loss:0.4573  g_loss:1.6981
# epoch:3752  d_loss:0.4494  g_loss:1.7897
# epoch:3753  d_loss:0.4598  g_loss:1.7077
# epoch:3754  d_loss:0.5431  g_loss:1.4763
# epoch:3755  d_loss:0.5709  g_loss:1.6789
# epoch:3756  d_loss:0.6566  g_loss:1.4987
# epoch:3757  d_loss:0.4363  g_loss:1.8127
# epoch:3758  d_loss:0.4198  g_loss:1.6099
# epoch:3759  d_loss:0.4388  g_loss:1.7878
# epoch:3760  d_loss:0.5892  g_loss:1.4921
# epoch:3761  d_loss:0.5768  g_loss:1.3176
# epoch:3762  d_loss:0.4568  g_loss:1.6251
# epoch:3763  d_loss:0.5158  g_loss:1.9141
# epoch:3764  d_loss:0.4722  g_loss:2.2413
# epoch:3765  d_loss:0.4789  g_loss:1.9381
# epoch:3766  d_loss:0.3914  g_loss:1.9690
# epoch:3767  d_loss:0.4651  g_loss:1.7122
# epoch:3768  d_loss:0.3750  g_loss:1.9000
# epoch:3769  d_loss:0.4199  g_loss:1.3027
# epoch:3770  d_loss:0.4306  g_loss:1.6482
# epoch:3771  d_loss:0.3083  g_loss:1.8821
# epoch:3772  d_loss:0.4204  g_loss:1.8731
# epoch:3773  d_loss:0.4441  g_loss:2.3653
# epoch:3774  d_loss:0.4365  g_loss:1.5847
# epoch:3775  d_loss:0.5552  g_loss:1.6950
# epoch:3776  d_loss:0.4638  g_loss:1.3892
# epoch:3777  d_loss:0.4994  g_loss:1.6422
# epoch:3778  d_loss:0.4411  g_loss:2.0200
# epoch:3779  d_loss:0.5217  g_loss:1.3574
# epoch:3780  d_loss:0.3819  g_loss:1.9326
# epoch:3781  d_loss:0.4413  g_loss:1.6027
# epoch:3782  d_loss:0.5335  g_loss:1.6904
# epoch:3783  d_loss:0.5081  g_loss:1.8028
# epoch:3784  d_loss:0.4990  g_loss:1.6151
# epoch:3785  d_loss:0.4441  g_loss:1.8883
# epoch:3786  d_loss:0.4188  g_loss:2.0839
# epoch:3787  d_loss:0.5185  g_loss:2.0275
# epoch:3788  d_loss:0.6245  g_loss:1.5929
# epoch:3789  d_loss:0.5067  g_loss:1.5729
# epoch:3790  d_loss:0.5287  g_loss:1.4611
# epoch:3791  d_loss:0.6288  g_loss:1.3370
# epoch:3792  d_loss:0.3884  g_loss:1.5679
# epoch:3793  d_loss:0.3995  g_loss:1.7691
# epoch:3794  d_loss:0.4450  g_loss:1.8499
# epoch:3795  d_loss:0.5279  g_loss:1.5037
# epoch:3796  d_loss:0.5920  g_loss:1.7672
# epoch:3797  d_loss:0.4248  g_loss:1.7875
# epoch:3798  d_loss:0.6346  g_loss:1.6002
# epoch:3799  d_loss:0.5742  g_loss:1.6563
# epoch:3800  d_loss:0.4770  g_loss:1.6081
# epoch:3801  d_loss:0.5113  g_loss:1.7734
# epoch:3802  d_loss:0.4207  g_loss:1.8279
# epoch:3803  d_loss:0.3209  g_loss:2.2919
# epoch:3804  d_loss:0.3983  g_loss:1.9337
# epoch:3805  d_loss:0.5250  g_loss:2.1891
# epoch:3806  d_loss:0.6337  g_loss:1.7481
# epoch:3807  d_loss:0.5521  g_loss:1.2868
# epoch:3808  d_loss:0.5316  g_loss:1.6335
# epoch:3809  d_loss:0.5973  g_loss:1.5006
# epoch:3810  d_loss:0.4774  g_loss:1.6505
# epoch:3811  d_loss:0.5866  g_loss:1.8306
# epoch:3812  d_loss:0.4268  g_loss:1.8168
# epoch:3813  d_loss:0.5517  g_loss:2.0133
# epoch:3814  d_loss:0.4604  g_loss:2.0290
# epoch:3815  d_loss:0.4880  g_loss:1.9958
# epoch:3816  d_loss:0.4951  g_loss:1.5191
# epoch:3817  d_loss:0.4194  g_loss:1.7114
# epoch:3818  d_loss:0.5279  g_loss:2.1054
# epoch:3819  d_loss:0.3712  g_loss:1.6837
# epoch:3820  d_loss:0.5088  g_loss:1.2542
# epoch:3821  d_loss:0.4219  g_loss:1.5957
# epoch:3822  d_loss:0.4579  g_loss:1.8661
# epoch:3823  d_loss:0.4837  g_loss:1.7100
# epoch:3824  d_loss:0.3707  g_loss:2.0334
# epoch:3825  d_loss:0.5655  g_loss:1.9780
# epoch:3826  d_loss:0.5498  g_loss:1.7148
# epoch:3827  d_loss:0.6576  g_loss:1.3984
# epoch:3828  d_loss:0.3355  g_loss:1.5941
# epoch:3829  d_loss:0.5742  g_loss:1.3974
# epoch:3830  d_loss:0.5357  g_loss:1.6586
# epoch:3831  d_loss:0.3248  g_loss:2.3751
# epoch:3832  d_loss:0.5413  g_loss:1.8597
# epoch:3833  d_loss:0.3822  g_loss:1.7270
# epoch:3834  d_loss:0.4540  g_loss:1.3764
# epoch:3835  d_loss:0.6156  g_loss:1.2578
# epoch:3836  d_loss:0.5618  g_loss:1.1863
# epoch:3837  d_loss:0.4154  g_loss:1.6513
# epoch:3838  d_loss:0.3259  g_loss:1.9673
# epoch:3839  d_loss:0.5049  g_loss:2.3424
# epoch:3840  d_loss:0.4283  g_loss:1.9449
# epoch:3841  d_loss:0.5573  g_loss:1.4755
# epoch:3842  d_loss:0.4901  g_loss:1.4823
# epoch:3843  d_loss:0.4745  g_loss:1.3490
# epoch:3844  d_loss:0.3750  g_loss:1.8786
# epoch:3845  d_loss:0.6342  g_loss:1.8171
# epoch:3846  d_loss:0.5041  g_loss:1.7465
# epoch:3847  d_loss:0.5185  g_loss:1.7954
# epoch:3848  d_loss:0.4420  g_loss:1.4160
# epoch:3849  d_loss:0.4085  g_loss:1.7538
# epoch:3850  d_loss:0.4503  g_loss:1.9060
# epoch:3851  d_loss:0.4630  g_loss:1.6509
# epoch:3852  d_loss:0.3968  g_loss:1.9777
# epoch:3853  d_loss:0.4149  g_loss:1.8170
# epoch:3854  d_loss:0.4744  g_loss:2.1289
# epoch:3855  d_loss:0.4563  g_loss:1.9344
# epoch:3856  d_loss:0.4043  g_loss:2.2009
# epoch:3857  d_loss:0.5167  g_loss:1.6989
# epoch:3858  d_loss:0.4671  g_loss:1.9758
# epoch:3859  d_loss:0.5467  g_loss:1.5195
# epoch:3860  d_loss:0.5023  g_loss:2.0204
# epoch:3861  d_loss:0.4410  g_loss:1.4417
# epoch:3862  d_loss:0.4749  g_loss:1.6758
# epoch:3863  d_loss:0.6279  g_loss:1.2196
# epoch:3864  d_loss:0.4783  g_loss:1.6512
# epoch:3865  d_loss:0.4881  g_loss:1.8512
# epoch:3866  d_loss:0.4457  g_loss:1.5599
# epoch:3867  d_loss:0.4443  g_loss:1.6101
# epoch:3868  d_loss:0.5902  g_loss:1.3550
# epoch:3869  d_loss:0.3014  g_loss:1.7494
# epoch:3870  d_loss:0.5748  g_loss:1.5219
# epoch:3871  d_loss:0.5121  g_loss:1.5527
# epoch:3872  d_loss:0.2870  g_loss:2.0359
# epoch:3873  d_loss:0.4785  g_loss:2.1073
# epoch:3874  d_loss:0.4854  g_loss:1.9328
# epoch:3875  d_loss:0.5720  g_loss:1.5497
# epoch:3876  d_loss:0.4882  g_loss:1.6702
# epoch:3877  d_loss:0.4783  g_loss:1.2853
# epoch:3878  d_loss:0.5684  g_loss:1.3503
# epoch:3879  d_loss:0.4535  g_loss:1.4318
# epoch:3880  d_loss:0.3926  g_loss:2.2232
# epoch:3881  d_loss:0.5391  g_loss:2.1627
# epoch:3882  d_loss:0.4341  g_loss:1.9598
# epoch:3883  d_loss:0.4063  g_loss:1.8678
# epoch:3884  d_loss:0.4365  g_loss:1.4415
# epoch:3885  d_loss:0.2995  g_loss:1.6834
# epoch:3886  d_loss:0.3902  g_loss:1.6096
# epoch:3887  d_loss:0.5104  g_loss:1.6403
# epoch:3888  d_loss:0.4274  g_loss:1.7369
# epoch:3889  d_loss:0.3627  g_loss:1.9193
# epoch:3890  d_loss:0.4663  g_loss:1.6466
# epoch:3891  d_loss:0.4979  g_loss:1.6217
# epoch:3892  d_loss:0.5248  g_loss:1.4851
# epoch:3893  d_loss:0.3442  g_loss:1.5821
# epoch:3894  d_loss:0.5118  g_loss:1.7748
# epoch:3895  d_loss:0.4907  g_loss:1.8477
# epoch:3896  d_loss:0.5747  g_loss:1.6469
# epoch:3897  d_loss:0.4035  g_loss:1.7383
# epoch:3898  d_loss:0.5289  g_loss:1.6759
# epoch:3899  d_loss:0.5390  g_loss:1.7169
# epoch:3900  d_loss:0.5260  g_loss:1.7588
# epoch:3901  d_loss:0.5870  g_loss:1.9482
# epoch:3902  d_loss:0.5136  g_loss:1.6922
# epoch:3903  d_loss:0.5880  g_loss:1.9061
# epoch:3904  d_loss:0.4226  g_loss:1.9625
# epoch:3905  d_loss:0.5175  g_loss:1.5235
# epoch:3906  d_loss:0.6216  g_loss:1.1570
# epoch:3907  d_loss:0.5568  g_loss:1.4550
# epoch:3908  d_loss:0.4880  g_loss:1.6526
# epoch:3909  d_loss:0.5010  g_loss:1.8552
# epoch:3910  d_loss:0.5923  g_loss:1.8525
# epoch:3911  d_loss:0.5031  g_loss:1.7214
# epoch:3912  d_loss:0.5651  g_loss:1.8688
# epoch:3913  d_loss:0.3503  g_loss:2.0807
# epoch:3914  d_loss:0.4640  g_loss:2.0369
# epoch:3915  d_loss:0.5611  g_loss:1.2786
# epoch:3916  d_loss:0.5056  g_loss:1.5598
# epoch:3917  d_loss:0.3982  g_loss:1.6813
# epoch:3918  d_loss:0.5282  g_loss:1.7611
# epoch:3919  d_loss:0.4198  g_loss:1.9518
# epoch:3920  d_loss:0.4778  g_loss:1.5791
# epoch:3921  d_loss:0.4027  g_loss:1.6940
# epoch:3922  d_loss:0.3959  g_loss:1.9609
# epoch:3923  d_loss:0.4452  g_loss:1.8326
# epoch:3924  d_loss:0.3787  g_loss:2.2958
# epoch:3925  d_loss:0.5233  g_loss:1.9692
# epoch:3926  d_loss:0.4742  g_loss:1.7483
# epoch:3927  d_loss:0.6252  g_loss:1.5337
# epoch:3928  d_loss:0.4271  g_loss:1.4157
# epoch:3929  d_loss:0.5389  g_loss:1.7210
# epoch:3930  d_loss:0.3193  g_loss:1.5979
# epoch:3931  d_loss:0.3510  g_loss:1.6467
# epoch:3932  d_loss:0.4408  g_loss:1.5431
# epoch:3933  d_loss:0.5309  g_loss:1.5888
# epoch:3934  d_loss:0.4251  g_loss:1.9613
# epoch:3935  d_loss:0.4006  g_loss:1.6718
# epoch:3936  d_loss:0.4842  g_loss:1.8066
# epoch:3937  d_loss:0.5105  g_loss:1.6841
# epoch:3938  d_loss:0.5191  g_loss:1.4817
# epoch:3939  d_loss:0.5973  g_loss:1.4764
# epoch:3940  d_loss:0.4619  g_loss:1.4152
# epoch:3941  d_loss:0.4078  g_loss:2.1502
# epoch:3942  d_loss:0.5471  g_loss:1.9563
# epoch:3943  d_loss:0.5795  g_loss:1.8858
# epoch:3944  d_loss:0.5321  g_loss:1.4407
# epoch:3945  d_loss:0.5681  g_loss:1.5961
# epoch:3946  d_loss:0.4343  g_loss:1.8073
# epoch:3947  d_loss:0.3872  g_loss:1.9447
# epoch:3948  d_loss:0.5889  g_loss:1.9258
# epoch:3949  d_loss:0.4276  g_loss:1.4892
# epoch:3950  d_loss:0.3817  g_loss:1.8074
# epoch:3951  d_loss:0.4046  g_loss:1.8055
# epoch:3952  d_loss:0.3980  g_loss:1.7340
# epoch:3953  d_loss:0.3802  g_loss:1.8294
# epoch:3954  d_loss:0.4811  g_loss:2.3270
# epoch:3955  d_loss:0.3943  g_loss:2.2969
# epoch:3956  d_loss:0.4472  g_loss:2.0957
# epoch:3957  d_loss:0.4951  g_loss:1.6508
# epoch:3958  d_loss:0.4624  g_loss:1.2646
# epoch:3959  d_loss:0.4457  g_loss:1.2199
# epoch:3960  d_loss:0.3640  g_loss:1.9406
# epoch:3961  d_loss:0.4133  g_loss:2.0380
# epoch:3962  d_loss:0.4467  g_loss:2.3349
# epoch:3963  d_loss:0.4858  g_loss:2.1455
# epoch:3964  d_loss:0.4701  g_loss:2.0913
# epoch:3965  d_loss:0.5376  g_loss:1.8499
# epoch:3966  d_loss:0.4453  g_loss:1.5434
# epoch:3967  d_loss:0.4036  g_loss:1.6718
# epoch:3968  d_loss:0.4777  g_loss:1.5345
# epoch:3969  d_loss:0.5111  g_loss:1.9659
# epoch:3970  d_loss:0.3584  g_loss:2.1940
# epoch:3971  d_loss:0.4570  g_loss:2.3396
# epoch:3972  d_loss:0.5061  g_loss:1.7886
# epoch:3973  d_loss:0.4204  g_loss:2.0780
# epoch:3974  d_loss:0.6898  g_loss:1.3428
# epoch:3975  d_loss:0.4844  g_loss:1.6336
# epoch:3976  d_loss:0.5857  g_loss:1.4362
# epoch:3977  d_loss:0.5133  g_loss:1.7009
# epoch:3978  d_loss:0.5338  g_loss:2.1438
# epoch:3979  d_loss:0.3969  g_loss:1.7693
# epoch:3980  d_loss:0.5869  g_loss:1.2200
# epoch:3981  d_loss:0.5058  g_loss:1.6125
# epoch:3982  d_loss:0.5042  g_loss:1.2859
# epoch:3983  d_loss:0.6348  g_loss:1.6743
# epoch:3984  d_loss:0.5285  g_loss:1.7498
# epoch:3985  d_loss:0.5575  g_loss:1.8742
# epoch:3986  d_loss:0.4318  g_loss:2.0628
# epoch:3987  d_loss:0.4923  g_loss:2.5204
# epoch:3988  d_loss:0.5575  g_loss:2.1754
# epoch:3989  d_loss:0.4412  g_loss:1.9789
# epoch:3990  d_loss:0.5053  g_loss:1.6964
# epoch:3991  d_loss:0.3700  g_loss:1.8244
# epoch:3992  d_loss:0.3097  g_loss:1.8278
# epoch:3993  d_loss:0.4276  g_loss:1.7840
# epoch:3994  d_loss:0.5564  g_loss:1.8310
# epoch:3995  d_loss:0.5386  g_loss:1.5786
# epoch:3996  d_loss:0.4861  g_loss:1.4213
# epoch:3997  d_loss:0.3909  g_loss:1.5848
# epoch:3998  d_loss:0.4736  g_loss:1.3799
# epoch:3999  d_loss:0.4240  g_loss:2.0245
# epoch:4000  d_loss:0.3425  g_loss:2.1546
# C:\Users\chang\anaconda3\envs\changho\lib\site-packages\ipykernel_launcher.py:91: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
